# %%
import Model as md
import Resnet as res
import data as dta
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms as T
from torch.utils.data import DataLoader
from absl import app
from absl import flags
from absl import logging
import os
from tqdm import tqdm

from torch.cuda import amp
import pandas as pd
import math
from torchsummary import summary
from pytorch_grad_cam import GradCAM, ScoreCAM, GradCAMPlusPlus, AblationCAM, XGradCAM, EigenCAM
from pytorch_grad_cam.utils.image import show_cam_on_image
import numpy as np
from matplotlib import pyplot as plt

# %%
# !pip install grad-cam
# !pip install torchsummary
# !pip install ttach
# Out:
# Collecting grad-cam
#   Downloading grad-cam-1.2.9.tar.gz (1.7 MB)
#      |████████████████████████████████| 1.7 MB 146 kB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Building wheels for collected packages: grad-cam
#   Building wheel for grad-cam (PEP 517) ... done
#   Created wheel for grad-cam: filename=grad_cam-1.2.9-py3-none-any.whl size=15636 sha256=40c4948247d69a812af3a96953f2d760d4d2a6c5c61d714a196627ab1f41d61f
#   Stored in directory: /root/.cache/pip/wheels/01/9b/56/e42ffe3389fe4710557ddae904dbcbf615016748d387907e4f
# Successfully built grad-cam
# Installing collected packages: grad-cam
# Successfully installed grad-cam-1.2.9
# Collecting torchsummary
#   Downloading torchsummary-1.5.1-py3-none-any.whl (2.8 kB)
# Installing collected packages: torchsummary
# Successfully installed torchsummary-1.5.1
# Collecting ttach
#   Downloading ttach-0.0.3-py3-none-any.whl (9.8 kB)
# Installing collected packages: ttach
# Successfully installed ttach-0.0.3

# %%
encoder = res.ResNet50().cuda()
#proj_head = md.Projection_Head(encoder.representation_dim, 1).cuda()
sup_head = md.Supervised_Head(encoder.representation_dim, 5).cuda()

# %%
transf_eval = T.Compose([
    T.CenterCrop(395),
    T.Resize(330),
    T.ToTensor(),
])

# %%
astro_ds = dta.AstroDataset('grad_cam.csv', 'imagenes_clasificadas_nair/', transform=transf_eval)
dataset_astro = DataLoader(astro_ds,batch_size=5, shuffle=False,num_workers=6)

# %%
checkpoint = torch.load('finetuned_model_weights/model.pt')
encoder.load_state_dict(checkpoint['encoder'])
#proj_head.load_state_dict(checkpoint['projection_head'], strict=False)
sup_head.load_state_dict(checkpoint['supervised_head'])
# Out:
# <All keys matched successfully>

# %%
summary(encoder, (3,112,112))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 56, 56]           9,408
#        BatchNorm2d-2           [-1, 64, 56, 56]             128
#               ReLU-3           [-1, 64, 56, 56]               0
#          MaxPool2d-4           [-1, 64, 28, 28]               0
#       StemImageNet-5           [-1, 64, 28, 28]               0
#             Conv2d-6           [-1, 64, 28, 28]           4,096
#        BatchNorm2d-7           [-1, 64, 28, 28]             128
#               ReLU-8           [-1, 64, 28, 28]               0
#             Conv2d-9           [-1, 64, 28, 28]          36,864
#       BatchNorm2d-10           [-1, 64, 28, 28]             128
#              ReLU-11           [-1, 64, 28, 28]               0
#            Conv2d-12          [-1, 256, 28, 28]          16,384
#       BatchNorm2d-13          [-1, 256, 28, 28]             512
#            Conv2d-14          [-1, 256, 28, 28]          16,384
#       BatchNorm2d-15          [-1, 256, 28, 28]             512
#              ReLU-16          [-1, 256, 28, 28]               0
#        Bottleneck-17          [-1, 256, 28, 28]               0
#            Conv2d-18           [-1, 64, 28, 28]          16,384
#       BatchNorm2d
#           Conv2d-135            [-1, 256, 7, 7]         589,824
#      BatchNorm2d-136            [-1, 256, 7, 7]             512
#             ReLU-137            [-1, 256, 7, 7]               0
#           Conv2d-138           [-1, 1024, 7, 7]         262,144
#      BatchNorm2d-139           [-1, 1024, 7, 7]           2,048
#             ReLU-140           [-1, 1024, 7, 7]               0
#       Bottleneck-141           [-1, 1024, 7, 7]               0
#           Conv2d-142            [-1, 512, 7, 7]         524,288
#      BatchNorm2d-143            [-1, 512, 7, 7]           1,024
#             ReLU-144            [-1, 512, 7, 7]               0
#           Conv2d-145            [-1, 512, 4, 4]       2,359,296
#      BatchNorm2d-146            [-1, 512, 4, 4]           1,024
#             ReLU-147            [-1, 512, 4, 4]               0
#           Conv2d-148           [-1, 2048, 4, 4]       1,048,576
#      BatchNorm2d-149           [-1, 2048, 4, 4]           4,096
#           Conv2d-150           [-1, 2048, 4, 4]       2,097,152
#      BatchNorm2d-151           [-1, 2048, 4, 4]           4,096
#             ReLU-152           [-1, 2048, 4, 4]               0
#       Bottleneck-153           [-1, 2048, 4, 4]               0
#           Conv2d-154            [-1, 512, 4, 4]       1,048,576
#      BatchNorm2d-155            [-1, 512, 4, 4]           1,024
#             ReLU-156            [-1, 512, 4, 4]               0
#           Conv2d-157            [-1, 512, 4, 4]       2,359,296
#      BatchNorm2d-158            [-1, 512, 4, 4]           1,024
#             ReLU-159            [-1, 512, 4, 4]               0
#           Conv2d-160           [-1, 2048, 4, 4]       1,048,576
#      BatchNorm2d-161           [-1, 2048, 4, 4]           4,096
#             ReLU-162           [-1, 2048, 4, 4]               0
#       Bottleneck-163           [-1, 2048, 4, 4]               0
#           Conv2d-164            [-1, 512, 4, 4]       1,048,576
#      BatchNorm2d-165            [-1, 512, 4, 4]           1,024
#             ReLU-166            [-1, 512, 4, 4]               0
#           Conv2d-167            [-1, 512, 4, 4]       2,359,296
#      BatchNorm2d-168            [-1, 512, 4, 4]           1,024
#             ReLU-169            [-1, 512, 4, 4]               0
#           Conv2d-170           [-1, 2048, 4, 4]       1,048,576
#      BatchNorm2d-171           [-1, 2048, 4, 4]           4,096
#             ReLU-172           [-1, 2048, 4, 4]               0
#       Bottleneck-173           [-1, 2048, 4, 4]               0
# AdaptiveAvgPool2d-174           [-1, 2048, 1, 1]               0
# ================================================================
# Total params: 23,508,032
# Trainable params: 23,508,032
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.14
# Forward/backward pass size (MB): 73.07
# Params size (MB): 89.68
# Estimated Total Size (MB): 162.89
# ----------------------------------------------------------------

# %%
encoder.layer4[-1]
# Out:
# Bottleneck(
#   (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
# )

# %%
class AstroModel(nn.Module):
    def __init__(self, encoder, supervised_head):
        super(AstroModel, self).__init__()
        self.encoder = encoder
        #self.projection_head = projection_head
        self.supervised_head = supervised_head
        
    def forward(self, x):
        x = self.encoder(x)
        #x = self.projection_head(x)
        x = self.supervised_head(x)
        return x
    
    def val_mode(self):
        self.encoder.eval()
        self.supervised_head.eval()

# %%
model = AstroModel(encoder, sup_head)
tensors = next(iter(dataset_astro))
tensors = tensors[0]
tensors.shape
# Out:
# torch.Size([5, 3, 330, 330])

# %%
cam = GradCAMPlusPlus(model=model, target_layer=model.encoder.layer4[-1], use_cuda=True)

# %%
grayscale_cam = cam(input_tensor=tensors, target_category=None)#(0,1,2,3,4))
# Out:
# /opt/conda/lib/python3.8/site-packages/torch/nn/modules/module.py:795: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "

# %%
grayscale_cam[0].shape
# Out:
# (330, 330)

# %%
visualization = show_cam_on_image(np.moveaxis(tensors[0].detach().cpu().numpy(),0,-1), grayscale_cam[0])

# %%
plt.imshow(visualization)

# %%
# !pip install torch-lucent
# Out:
# Collecting torch-lucent
#   Downloading torch_lucent-0.1.8-py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 1.1 MB/s eta 0:00:011
# Requirement already satisfied: torch>=1.5.0 in /opt/conda/lib/python3.8/site-packages (from torch-lucent) (1.9.0a0+df837d0)
# Requirement already satisfied: pytest in /opt/conda/lib/python3.8/site-packages (from torch-lucent) (6.2.2)
# Collecting coveralls
#   Downloading coveralls-3.0.1-py2.py3-none-any.whl (13 kB)
# Collecting kornia<=0.4.1
#   Downloading kornia-0.4.1-py2.py3-none-any.whl (225 kB)
#      |████████████████████████████████| 225 kB 2.9 MB/s eta 0:00:01
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.8/site-packages (from torch-lucent) (0.9.0a0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.8/site-packages (from torch-lucent) (4.53.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.8/site-packages (from torch-lucent) (1.19.2)
# Requirement already satisfied: ipython in /opt/conda/lib/python3.8/site-packages (from torch-lucent) (7.21.0)
# Requirement already satisfied: coverage in /opt/conda/lib/python3.8/site-packages (from torch-lucent) (5.5)
# Collecting pytest-mock
#   Downloading pytest_mock-3.6.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.8/site-packages (from torch-lucent) (8.2.0)
# Requirement already satisfied: future in /opt/conda/lib/python3.8/site-packages (from torch-lucent) (0.18.2)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.8/site-packages (from torch-lucent) (0.24.2)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.8/site-packages (from torch-lucent) (4.4.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.8/site-packages (from torch>=1.5.0->torch-lucent) (3.7.4.3)
# Requirement already satisfied: py>=1.8.2 in /opt/conda/lib/python3.8/site-packages (from pytest->torch-lucent) (1.10.0)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /opt/conda/lib/python3.8/site-packages (from pytest->torch-lucent) (0.13.1)
# Requirement already satisfied: attrs>=19.2.0 in /opt/conda/lib/python3.8/site-packages (from pytest->torch-lucent) (20.3.0)
# Requirement already satisfied: iniconfig in /opt/conda/lib/python3.8/site-packages (from pytest->torch-lucent) (1.1.1)
# Requirement already satisfied: toml in /opt/conda/lib/python3.8/site-packages (from pytest->torch-lucent) (0.10.2)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.8/site-packages (from pytest->torch-lucent) (20.9)
# Requirement already satisfied: requests>=1.0.0 in /opt/conda/lib/python3.8/site-packages (from coveralls->torch-lucent) (2.24.0)
# Collecting docopt>=0.6.1
#   Downloading docopt-0.6.2.tar.gz (25 kB)
# Requirement already satisfied: traitlets>=4.2 in /opt/conda/lib/python3.8/site-packages (from ipython->torch-lucent) (5.0.5)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /opt/conda/lib/python3.8/site-packages (from ipython->torch-lucent) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.8/site-packages (from ipython->torch-lucent) (0.17.0)
# Requirement already satisfied: setuptools>=18.5 in /opt/conda/lib/python3.8/site-packages (from ipython->torch-lucent) (50.3.1.post20201107)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.8/site-packages (from ipython->torch-lucent) (0.7.5)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.8/site-packages (from ipython->torch-lucent) (0.2.0)
# Requirement already satisfied: pygments in /opt/conda/lib/python3.8/site-packages (from ipython->torch-lucent) (2.8.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/conda/lib/python3.8/site-packages (from ipython->torch-lucent) (3.0.8)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.8/site-packages (from scikit-learn->torch-lucent) (1.0.1)
# Requirement already satisfied: scipy>=0.19.1 in /opt/conda/lib/python3.8/site-packages (from scikit-learn->torch-lucent) (1.6.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.8/site-packages (from scikit-learn->torch-lucent) (2.1.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.8/site-packages (from packaging->pytest->torch-lucent) (2.4.7)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests>=1.0.0->coveralls->torch-lucent) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests>=1.0.0->coveralls->torch-lucent) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests>=1.0.0->coveralls->torch-lucent) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests>=1.0.0->coveralls->torch-lucent) (2.10)
# Requirement already satisfied: ipython-genutils in /opt/conda/lib/python3.8/site-packages (from traitlets>=4.2->ipython->torch-lucent) (0.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.8/site-packages (from pexpect>4.3; sys_platform != "win32"->ipython->torch-lucent) (0.7.0)
# Requirement already satisfied: parso>=0.7.0 in /opt/conda/lib/python3.8/site-packages (from jedi>=0.16->ipython->torch-lucent) (0.8.1)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->torch-lucent) (0.2.5)
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13704 sha256=dbcd511d81bb9a765b961e303f7bc7808d72dfc673e18c51526921bf990b1ba2
#   Stored in directory: /root/.cache/pip/wheels/56/ea/58/ead137b087d9e326852a851351d1debf4ada529b6ac0ec4e8c
# Successfully built docopt
# Installing collected packages: docopt, coveralls, kornia, pytest-mock, torch-lucent
# Successfully installed coveralls-3.0.1 docopt-0.6.2 kornia-0.4.1 pytest-mock-3.6.1 torch-lucent-0.1.8

# %%
from lucent.optvis import render, param, transform, objectives
from lucent.modelzoo.util import get_model_layers

# %%
get_model_layers(model)
# Out:
# ['encoder',
#  'encoder_stem',
#  'encoder_stem_conv1',
#  'encoder_stem_bn1',
#  'encoder_stem_relu',
#  'encoder_stem_maxpool',
#  'encoder_layer1',
#  'encoder_layer1_0',
#  'encoder_layer1_0_conv1',
#  'encoder_layer1_0_bn1',
#  'encoder_layer1_0_conv2',
#  'encoder_layer1_0_bn2',
#  'encoder_layer1_0_conv3',
#  'encoder_layer1_0_bn3',
#  'encoder_layer1_0_relu',
#  'encoder_layer1_0_downsample',
#  'encoder_layer1_0_downsample_0',
#  'encoder_layer1_0_downsample_1',
#  'encoder_layer1_1',
#  'encoder_layer1_1_conv1',
#  'encoder_layer1_1_bn1',
#  'encoder_layer1_1_conv2',
#  'encoder_layer1_1_bn2',
#  'encoder_layer1_1_conv3',
#  'encoder_layer1_1_bn3',
#  'encoder_layer1_1_relu',
#  'encoder_layer1_2',
#  'encoder_layer1_2_conv1',
#  'encoder_layer1_2_bn1',
#  'encoder_layer1_2_conv2',
#  'encoder_layer1_2_bn2',
#  'encoder_layer1_2_conv3',
#  'encoder_layer1_2_bn3',
#  'encoder_layer1_2_relu',
#  'encoder_layer2',
#  'encoder_layer2_0',
#  'encoder_layer2_0_conv1',
#  'encoder_layer2_0_bn1',
#  'encoder_layer2_0_conv2',
#  'encoder_layer2_0_bn2',
#  'encoder_layer2_0_conv3',
#  'encoder_layer2_0_bn3',
#  'encoder_layer2_0_relu',
#  'encoder_layer2_0_downsample',
#  'encoder_layer2_0_downsample_0',
#  'encoder_layer2_0_downsample_1',
#  'encoder_layer2_1',
#  'encoder_layer2_1_conv1',
#  'encoder_layer2_1_bn1',
#  'encoder_layer2_1_conv2',
#  'encoder_layer2_1_bn2',
#  'encoder_layer2_1_conv3',
#  'encoder_layer2_1_bn3',
#  'encoder_layer2_1_relu',
#  'encoder_layer2_2',
#  'encoder_layer2_2_conv1',
#  'encoder_layer2_2_bn1',
#  'encoder_layer2_2_conv2',
#  'encoder_layer2_2_bn2',
#  'encoder_layer2_2_conv3',
#  'encoder_layer2_2_bn3',
#  'encoder_layer2_2_relu',
#  'encoder_layer2_3',
#  'encoder_layer2_3_conv1',
#  'encoder_layer2_3_bn1',
#  'encoder_layer2_3_conv2',
#  'encoder_layer2_3_bn2',
#  'encoder_layer2_3_conv3',
#  'encoder_layer2_3_bn3',
#  'encoder_layer2_3_relu',
#  'encoder_layer3',
#  'encoder_layer3_0',
#  'encoder_layer3_0_conv1',
#  'encoder_layer3_0_bn1',
#  'encoder_layer3_0_conv2',
#  'encoder_layer3_0_bn2',
#  'encoder_layer3_0_conv3',
#  'encoder_layer3_0_bn3',
#  'encoder_layer3_0_relu',
#  'encoder_layer3_0_downsample',
#  'encoder_layer3_0_downsample_0',
#  'encoder_layer3_0_downsample_1',
#  'encoder_layer3_1',
#  'encoder_layer3_1_conv1',
#  'encoder_layer3_1_bn1',
#  'encoder_layer3_1_conv2',
#  'encoder_layer3_1_bn2',
#  'encoder_layer3_1_conv3',
#  'encoder_layer3_1_bn3',
#  'encoder_layer3_1_relu',
#  'encoder_layer3_2',
#  'encoder_layer3_2_conv1',
#  'encoder_layer3_2_bn1',
#  'encoder_layer3_2_conv2',
#  'encoder_layer3_2_bn2',
#  'encoder_layer3_2_conv3',
#  'encoder_layer3_2_bn3',
#  'encoder_layer3_2_relu',
#  'encoder_layer3_3',
#  'encoder_layer3_3_conv1',
#  'encoder_layer3_3_bn1',
#  'encoder_layer3_3_conv2',
#  'encoder_layer3_3_bn2',
#  'encoder_layer3_3_conv3',
#  'encoder_layer3_3_bn3',
#  'encoder_layer3_3_relu',
#  'encoder_layer3_4',
#  'encoder_layer3_4_conv1',
#  'encoder_layer3_4_bn1',
#  'encoder_layer3_4_conv2',
#  'encoder_layer3_4_bn2',
#  'encoder_layer3_4_conv3',
#  'encoder_layer3_4_bn3',
#  'encoder_layer3_4_relu',
#  'encoder_layer3_5',
#  'encoder_layer3_5_conv1',
#  'encoder_layer3_5_bn1',
#  'encoder_layer3_5_conv2',
#  'encoder_layer3_5_bn2',
#  'encoder_layer3_5_conv3',
#  'encoder_layer3_5_bn3',
#  'encoder_layer3_5_relu',
#  'encoder_layer4',
#  'encoder_layer4_0',
#  'encoder_layer4_0_conv1',
#  'encoder_layer4_0_bn1',
#  'encoder_layer4_0_conv2',
#  'encoder_layer4_0_bn2',
#  'encoder_layer4_0_conv3',
#  'encoder_layer4_0_bn3',
#  'encoder_layer4_0_relu',
#  'encoder_layer4_0_downsample',
#  'encoder_layer4_0_downsample_0',
#  'encoder_layer4_0_downsample_1',
#  'encoder_layer4_1',
#  'encoder_layer4_1_conv1',
#  'encoder_layer4_1_bn1',
#  'encoder_layer4_1_conv2',
#  'encoder_layer4_1_bn2',
#  'encoder_layer4_1_conv3',
#  'encoder_layer4_1_bn3',
#  'encoder_layer4_1_relu',
#  'encoder_layer4_2',
#  'encoder_layer4_2_conv1',
#  'encoder_layer4_2_bn1',
#  'encoder_layer4_2_conv2',
#  'encoder_layer4_2_bn2',
#  'encoder_layer4_2_conv3',
#  'encoder_layer4_2_bn3',
#  'encoder_layer4_2_relu',
#  'encoder_avgpool',
#  'supervised_head',
#  'supervised_head_supervised_head']

# %%
model.eval()
_ = render.render_vis(model, "supervised_head:1", show_inline=True, save_image=False)
# Out:
# 100%|██████████| 512/512 [00:10<00:00, 50.08it/s]
# <div style="display: flex; flex-direction: row;"><div style="margin-right:10px; margin-top: 4px;">
#                             0 <br/>
#                             <img src="data:image/PNG;base64,..." style="image-rendering: pixelated;">
#                         </div></div>

# %%
plt.figure(figsize=(10,10),dpi=180)
plt.imshow(_[0][0])
plt.show()

# %%
from PIL import Image
im1 = Image.fromarray(np.uint8(_[0][0]*255))
im1
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FA588223550>

# %%
im1 = im1.resize((800,800), Image.LANCZOS)
im1
# Out:
# <PIL.Image.Image image mode=RGB size=800x800 at 0x7FA587794400>

# %%
im1.save('supervised_head:1.png')
