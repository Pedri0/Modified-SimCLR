# %%
import tensorflow.compat.v2 as tf
import pandas as pd
import numpy as np
import functools

import data_util_val

# %%
def build_input_fn(global_batch_size):
    #Build input function.
    #Args:
    #    global_batch_size: Global batch size.
    #Returns:
    #    A function that accepts a dict of params and returns a tuple of images and
    #    features, to be used as the input_fn in TPUEstimator.
    def _input_fn_(input_context):
        #Inner input function
        batch_size = input_context.get_per_replica_batch_size(global_batch_size)
        #logging.info('Global batch size: %d', global_batch_size)
        #logging.info('Per-replica batch size: %d', batch_size)
        preprocess_fn_finetune = get_preprocess_fn()
        num_classes = 5

        def map_fn(image, label):
            image = preprocess_fn_finetune(image)
            label = tf.one_hot(label, num_classes)
            return image, label

        #logging.info('Using Astro pretrain data')
        dataset = get_data_test()

        if input_context.num_input_pipelines > 1:
            dataset = dataset.shard(input_context.num_input_pipelines, input_context.input_pipeline_id)

        dataset = dataset.map(map_fn, num_parallel_calls=tf.data.experimental.AUTOTUNE)
        dataset = dataset.batch(batch_size, drop_remainder=True)
        dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
        return dataset

    return _input_fn_

def build_distributed_dataset(batch_size, strategy):
    input_fn = build_input_fn(batch_size)
    return strategy.experimental_distribute_datasets_from_function(input_fn)

def get_preprocess_fn():
    #Get function that accepts an image and returns a preprocessed image
    return functools.partial(
        data_util_val.preprocess_image,
        height = 112,
        width= 112)


def get_data_test():
    #logging.info('Loading Astro test data')
    data_dir = 'imagenes_clasificadas_nair/'
    def read_images(image_file, label):
        image = tf.io.read_file(data_dir + image_file)
        image = tf.image.decode_jpeg(image, channels = 3)
        return image, label
    
    AUTOTUNE = tf.data.experimental.AUTOTUNE
    df = pd.read_csv('nair_unbalanced_train.csv')
    file_paths = df['name'].values
    labels = df['new_class'].values
    labels = tf.convert_to_tensor(labels, dtype=tf.int64)
    ds_test = tf.data.Dataset.from_tensor_slices((file_paths, labels))
    ds_test = ds_test.map(read_images, num_parallel_calls =AUTOTUNE)
    return ds_test

def get_number_of_images(path_to_csv):
    df = pd.read_csv(path_to_csv)
    return df.shape[0]

# %%
strategy = tf.distribute.MirroredStrategy()
ds = build_distributed_dataset(8, strategy)
iterator = iter(ds)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)

# %%
#R152_sk1_x3
saved_model = tf.saved_model.load('checkpoint/saved_model/2513100/')
# Out:
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_5_layer_call_and_return_conditional_losses_111035) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_5_layer_call_and_return_conditional_losses_111035) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_5_layer_call_and_return_conditional_losses_111035) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_4_layer_call_and_return_conditional_losses_110815) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_4_layer_call_and_return_conditional_losses_110815) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_4_layer_call_and_return_conditional_losses_110815) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_10_layer_call_and_return_conditional_losses_112135) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_10_layer_call_and_return_conditional_losses_112135) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_10_layer_call_and_return_conditional_losses_112135) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_30_layer_call_and_return_conditional_losses_131507) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_30_layer_call_and_return_conditional_losses_131507) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_30_layer_call_and_return_conditional_losses_131507) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_37_layer_call_and_return_conditional_losses_132361) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_37_layer_call_and_return_conditional_losses_132361) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_37_layer_call_and_return_conditional_losses_132361) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_50_layer_call_and_return_conditional_losses_133947) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_50_layer_call_and_return_conditional_losses_133947) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_50_layer_call_and_return_conditional_losses_133947) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_14_layer_call_and_return_conditional_losses_129555) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_14_layer_call_and_return_conditional_losses_129555) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_14_layer_call_and_return_conditional_losses_129555) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_22_layer_call_and_return_conditional_losses_130531) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_22_layer_call_and_return_conditional_losses_130531) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_22_layer_call_and_return_conditional_losses_130531) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_49_layer_call_and_return_conditional_losses_120715) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_49_layer_call_and_return_conditional_losses_120715) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_49_layer_call_and_return_conditional_losses_120715) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_39_layer_call_and_return_conditional_losses_118515) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_39_layer_call_and_return_conditional_losses_118515) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_39_layer_call_and_return_conditional_losses_118515) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_24_layer_call_and_return_conditional_losses_130775) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_24_layer_call_and_return_conditional_losses_130775) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_24_layer_call_and_return_conditional_losses_130775) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_29_layer_call_and_return_conditional_losses_131385) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_29_layer_call_and_return_conditional_losses_131385) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_29_layer_call_and_return_conditional_losses_131385) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_14_layer_call_and_return_conditional_losses_113015) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_14_layer_call_and_return_conditional_losses_113015) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_14_layer_call_and_return_conditional_losses_113015) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_6_layer_call_and_return_conditional_losses_111255) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_6_layer_call_and_return_conditional_losses_111255) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_6_layer_call_and_return_conditional_losses_111255) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_48_layer_call_and_return_conditional_losses_133703) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_48_layer_call_and_return_conditional_losses_133703) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_48_layer_call_and_return_conditional_losses_133703) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_26_layer_call_and_return_conditional_losses_115655) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_26_layer_call_and_return_conditional_losses_115655) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_26_layer_call_and_return_conditional_losses_115655) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_52_layer_call_and_return_conditional_losses_121375) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_52_layer_call_and_return_conditional_losses_121375) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_52_layer_call_and_return_conditional_losses_121375) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_42_layer_call_and_return_conditional_losses_132971) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_42_layer_call_and_return_conditional_losses_132971) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_42_layer_call_and_return_conditional_losses_132971) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_16_layer_call_and_return_conditional_losses_113455) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_16_layer_call_and_return_conditional_losses_113455) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_16_layer_call_and_return_conditional_losses_113455) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_17_layer_call_and_return_conditional_losses_129921) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_17_layer_call_and_return_conditional_losses_129921) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_17_layer_call_and_return_conditional_losses_129921) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_layer_call_and_return_conditional_losses_109923) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_layer_call_and_return_conditional_losses_109923) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_layer_call_and_return_conditional_losses_109923) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_20_layer_call_and_return_conditional_losses_114335) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_20_layer_call_and_return_conditional_losses_114335) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_20_layer_call_and_return_conditional_losses_114335) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_27_layer_call_and_return_conditional_losses_115875) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_27_layer_call_and_return_conditional_losses_115875) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_27_layer_call_and_return_conditional_losses_115875) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_51_layer_call_and_return_conditional_losses_121155) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_51_layer_call_and_return_conditional_losses_121155) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_51_layer_call_and_return_conditional_losses_121155) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_37_layer_call_and_return_conditional_losses_118075) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_37_layer_call_and_return_conditional_losses_118075) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_37_layer_call_and_return_conditional_losses_118075) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_35_layer_call_and_return_conditional_losses_132117) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_35_layer_call_and_return_conditional_losses_132117) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_35_layer_call_and_return_conditional_losses_132117) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_38_layer_call_and_return_conditional_losses_118295) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_38_layer_call_and_return_conditional_losses_118295) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_38_layer_call_and_return_conditional_losses_118295) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_20_layer_call_and_return_conditional_losses_130287) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_20_layer_call_and_return_conditional_losses_130287) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_20_layer_call_and_return_conditional_losses_130287) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_40_layer_call_and_return_conditional_losses_132727) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_40_layer_call_and_return_conditional_losses_132727) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_40_layer_call_and_return_conditional_losses_132727) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_44_layer_call_and_return_conditional_losses_133215) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_44_layer_call_and_return_conditional_losses_133215) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_44_layer_call_and_return_conditional_losses_133215) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_5_layer_call_and_return_conditional_losses_128457) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_5_layer_call_and_return_conditional_losses_128457) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_5_layer_call_and_return_conditional_losses_128457) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_28_layer_call_and_return_conditional_losses_131263) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_28_layer_call_and_return_conditional_losses_131263) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_28_layer_call_and_return_conditional_losses_131263) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_46_layer_call_and_return_conditional_losses_120055) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_46_layer_call_and_return_conditional_losses_120055) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_46_layer_call_and_return_conditional_losses_120055) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_43_layer_call_and_return_conditional_losses_133093) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_43_layer_call_and_return_conditional_losses_133093) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_43_layer_call_and_return_conditional_losses_133093) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_25_layer_call_and_return_conditional_losses_115435) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_25_layer_call_and_return_conditional_losses_115435) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_25_layer_call_and_return_conditional_losses_115435) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_30_layer_call_and_return_conditional_losses_116535) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_30_layer_call_and_return_conditional_losses_116535) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_30_layer_call_and_return_conditional_losses_116535) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_4_layer_call_and_return_conditional_losses_128335) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_4_layer_call_and_return_conditional_losses_128335) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_4_layer_call_and_return_conditional_losses_128335) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_36_layer_call_and_return_conditional_losses_117855) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_36_layer_call_and_return_conditional_losses_117855) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_36_layer_call_and_return_conditional_losses_117855) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_55_layer_call_and_return_conditional_losses_127853) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_55_layer_call_and_return_conditional_losses_127853) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_55_layer_call_and_return_conditional_losses_127853) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_38_layer_call_and_return_conditional_losses_132483) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_38_layer_call_and_return_conditional_losses_132483) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_38_layer_call_and_return_conditional_losses_132483) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_24_layer_call_and_return_conditional_losses_115215) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_24_layer_call_and_return_conditional_losses_115215) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_24_layer_call_and_return_conditional_losses_115215) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_17_layer_call_and_return_conditional_losses_113675) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_17_layer_call_and_return_conditional_losses_113675) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_17_layer_call_and_return_conditional_losses_113675) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_46_layer_call_and_return_conditional_losses_133459) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_46_layer_call_and_return_conditional_losses_133459) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_46_layer_call_and_return_conditional_losses_133459) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_2_layer_call_and_return_conditional_losses_128091) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_2_layer_call_and_return_conditional_losses_128091) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_2_layer_call_and_return_conditional_losses_128091) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_32_layer_call_and_return_conditional_losses_131751) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_32_layer_call_and_return_conditional_losses_131751) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_32_layer_call_and_return_conditional_losses_131751) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_3_layer_call_and_return_conditional_losses_110595) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_3_layer_call_and_return_conditional_losses_110595) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_3_layer_call_and_return_conditional_losses_110595) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_48_layer_call_and_return_conditional_losses_120495) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_48_layer_call_and_return_conditional_losses_120495) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_48_layer_call_and_return_conditional_losses_120495) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_layer_call_and_return_conditional_losses_127522) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_layer_call_and_return_conditional_losses_127522) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_layer_call_and_return_conditional_losses_127522) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_51_layer_call_and_return_conditional_losses_134069) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_51_layer_call_and_return_conditional_losses_134069) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_51_layer_call_and_return_conditional_losses_134069) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_6_layer_call_and_return_conditional_losses_128579) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_6_layer_call_and_return_conditional_losses_128579) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_6_layer_call_and_return_conditional_losses_128579) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_53_layer_call_and_return_conditional_losses_121573) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_53_layer_call_and_return_conditional_losses_121573) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_53_layer_call_and_return_conditional_losses_121573) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_12_layer_call_and_return_conditional_losses_129311) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_12_layer_call_and_return_conditional_losses_129311) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_12_layer_call_and_return_conditional_losses_129311) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_7_layer_call_and_return_conditional_losses_128701) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_7_layer_call_and_return_conditional_losses_128701) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_7_layer_call_and_return_conditional_losses_128701) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_36_layer_call_and_return_conditional_losses_132239) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_36_layer_call_and_return_conditional_losses_132239) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_36_layer_call_and_return_conditional_losses_132239) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_40_layer_call_and_return_conditional_losses_118735) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_40_layer_call_and_return_conditional_losses_118735) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_40_layer_call_and_return_conditional_losses_118735) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_23_layer_call_and_return_conditional_losses_130653) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_23_layer_call_and_return_conditional_losses_130653) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_23_layer_call_and_return_conditional_losses_130653) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_31_layer_call_and_return_conditional_losses_116755) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_31_layer_call_and_return_conditional_losses_116755) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_31_layer_call_and_return_conditional_losses_116755) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_43_layer_call_and_return_conditional_losses_119395) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_43_layer_call_and_return_conditional_losses_119395) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_43_layer_call_and_return_conditional_losses_119395) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_16_layer_call_and_return_conditional_losses_129799) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_16_layer_call_and_return_conditional_losses_129799) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_16_layer_call_and_return_conditional_losses_129799) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_15_layer_call_and_return_conditional_losses_113235) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_15_layer_call_and_return_conditional_losses_113235) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_15_layer_call_and_return_conditional_losses_113235) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_42_layer_call_and_return_conditional_losses_119175) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_42_layer_call_and_return_conditional_losses_119175) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_42_layer_call_and_return_conditional_losses_119175) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_31_layer_call_and_return_conditional_losses_131629) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_31_layer_call_and_return_conditional_losses_131629) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_31_layer_call_and_return_conditional_losses_131629) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_1_layer_call_and_return_conditional_losses_110155) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_1_layer_call_and_return_conditional_losses_110155) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_1_layer_call_and_return_conditional_losses_110155) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_23_layer_call_and_return_conditional_losses_114995) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_23_layer_call_and_return_conditional_losses_114995) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_23_layer_call_and_return_conditional_losses_114995) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_12_layer_call_and_return_conditional_losses_112575) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_12_layer_call_and_return_conditional_losses_112575) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_12_layer_call_and_return_conditional_losses_112575) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_19_layer_call_and_return_conditional_losses_130165) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_19_layer_call_and_return_conditional_losses_130165) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_19_layer_call_and_return_conditional_losses_130165) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_29_layer_call_and_return_conditional_losses_116315) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_29_layer_call_and_return_conditional_losses_116315) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_29_layer_call_and_return_conditional_losses_116315) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_47_layer_call_and_return_conditional_losses_120275) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_47_layer_call_and_return_conditional_losses_120275) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_47_layer_call_and_return_conditional_losses_120275) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_18_layer_call_and_return_conditional_losses_113895) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_18_layer_call_and_return_conditional_losses_113895) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_18_layer_call_and_return_conditional_losses_113895) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_34_layer_call_and_return_conditional_losses_131995) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_34_layer_call_and_return_conditional_losses_131995) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_34_layer_call_and_return_conditional_losses_131995) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_22_layer_call_and_return_conditional_losses_114775) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_22_layer_call_and_return_conditional_losses_114775) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_22_layer_call_and_return_conditional_losses_114775) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_13_layer_call_and_return_conditional_losses_112795) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_13_layer_call_and_return_conditional_losses_112795) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_13_layer_call_and_return_conditional_losses_112795) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_10_layer_call_and_return_conditional_losses_129067) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_10_layer_call_and_return_conditional_losses_129067) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_10_layer_call_and_return_conditional_losses_129067) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_3_layer_call_and_return_conditional_losses_128213) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_3_layer_call_and_return_conditional_losses_128213) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_3_layer_call_and_return_conditional_losses_128213) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_18_layer_call_and_return_conditional_losses_130043) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_18_layer_call_and_return_conditional_losses_130043) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_18_layer_call_and_return_conditional_losses_130043) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_32_layer_call_and_return_conditional_losses_116975) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_32_layer_call_and_return_conditional_losses_116975) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_32_layer_call_and_return_conditional_losses_116975) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_47_layer_call_and_return_conditional_losses_133581) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_47_layer_call_and_return_conditional_losses_133581) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_47_layer_call_and_return_conditional_losses_133581) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_33_layer_call_and_return_conditional_losses_131873) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_33_layer_call_and_return_conditional_losses_131873) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_33_layer_call_and_return_conditional_losses_131873) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_21_layer_call_and_return_conditional_losses_130409) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_21_layer_call_and_return_conditional_losses_130409) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_21_layer_call_and_return_conditional_losses_130409) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_26_layer_call_and_return_conditional_losses_131019) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_26_layer_call_and_return_conditional_losses_131019) with ops with custom gradients. Will likely fail if a gradient is requested.
# ...
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference___call___127446) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_54_layer_call_and_return_conditional_losses_121771) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_54_layer_call_and_return_conditional_losses_121771) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_54_layer_call_and_return_conditional_losses_121771) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_27_layer_call_and_return_conditional_losses_131141) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_27_layer_call_and_return_conditional_losses_131141) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_27_layer_call_and_return_conditional_losses_131141) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_41_layer_call_and_return_conditional_losses_132849) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_41_layer_call_and_return_conditional_losses_132849) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_41_layer_call_and_return_conditional_losses_132849) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_49_layer_call_and_return_conditional_losses_133825) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_49_layer_call_and_return_conditional_losses_133825) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_49_layer_call_and_return_conditional_losses_133825) with ops with custom gradients. Will likely fail if a gradient is requested.

# %%
representations_list = []
#kmeans = MiniBatchKMeans(n_clusters=5)
for images, labels in iterator:
    representation = saved_model(images, trainable=False)['logits']
    representation = representation.numpy()
    #kmeans.partial_fit(representation)
    representations_list.append(representation)

# %%
representations_list
# Out:
# [array([[1.3351831 , 0.        , 0.        , ..., 0.29190707, 0.        ,
#          0.        ],
#         [1.3356578 , 0.        , 0.        , ..., 0.30727136, 0.        ,
#          0.        ],
#         [1.3522286 , 0.        , 0.        , ..., 0.3384427 , 0.        ,
#          0.        ],
#         ...,
#         [1.3270015 , 0.        , 0.        , ..., 0.2793661 , 0.        ,
#          0.        ],
#         [1.3336895 , 0.        , 0.        , ..., 0.2913698 , 0.        ,
#          0.        ],
#         [1.336417  , 0.        , 0.        , ..., 0.28456652, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3483564 , 0.        , 0.        , ..., 0.3160429 , 0.        ,
#          0.        ],
#         [1.3315346 , 0.        , 0.        , ..., 0.29029322, 0.        ,
#          0.        ],
#         [1.3516257 , 0.        , 0.        , ..., 0.3079007 , 0.        ,
#          0.        ],
#         ...,
#         [1.3395882 , 0.        , 0.        , ..., 0.32670206, 0.        ,
#          0.        ],
#         [1.3396448 , 0.        , 0.        , ..., 0.2929031 , 0.        ,
#          0.        ],
#         [1.344393  , 0.        , 0.        , ..., 0.3039835 , 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3494457 , 0.        , 0.        , ..., 0.29475707, 0.        ,
#          0.        ],
#         [1.3318267 , 0.        , 0.        , ..., 0.2831738 , 0.        ,
#          0.        ],
#         [1.3499286 , 0.        , 0.        , ..., 0.29383802, 0.        ,
#          0.        ],
#         ...,
#         [1.3387198 , 0.        , 0.        , ..., 0.2946026 , 0.        ,
#          0.        ],
#         [1.3517666 , 0.        , 0.        , ..., 0.31166795, 0.        ,
#          0.        ],
#         [1.3451498 , 0.        , 0.        , ..., 0.3296082 , 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3308661 , 0.        , 0.        , ..., 0.2870102 , 0.        ,
#          0.        ],
#         [1.3375161 , 0.        , 0.        , ..., 0.31864688, 0.        ,
#          0.        ],
#         [1.3443029 , 0.        , 0.        , ..., 0.3144614 , 0.        ,
#          0.        ],
#         ...,
#         [1.3588026 , 0.        , 0.        , ..., 0.315405  , 0.        ,
#          0.        ],
#         [1.357011  , 0.        , 0.        , ..., 0.2926917 , 0.        ,
#          0.        ],
#         [1.3309865 , 0.        , 0.        , ..., 0.3282719 , 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.336597  , 0.        , 0.        , ..., 0.293339  , 0.        ,
#          0.        ],
#         [1.3487461 , 0.        , 0.        , ..., 0.30295253, 0.        ,
#          0.        ],
#         [1.3396033 , 0.        , 0.        , ..., 0.2909234 , 0.        ,
#          0.        ],
#         ...,
#         [1.3644041 , 0.        , 0.        , ..., 0.3111911 , 0.        ,
#          0.        ],
#         [1.332725  , 0.        , 0.        , ..., 0.28632843, 0.        ,
#          0.        ],
#         [1.3404697 , 0.        , 0.        , ..., 0.3314576 , 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3615495 , 0.        , 0.        , ..., 0.29800898, 0.        ,
#          0.        ],
#         [1.3341974 , 0.        , 0.        , ..., 0.2848792 , 0.        ,
#          0.        ],
#         [1.3617746 , 0.        , 0.        , ..., 0.2977199 , 0.03477216,
#          0.        ],
#         ...,
#         [1.3333945 , 0.        , 0.        , ..., 0.28244856, 0.        ,
#          0.        ],
#         [1.3527682 , 0.        , 0.        , ..., 0.31996882, 0.        ,
#          0.        ],
#         [1.3339818 , 0.        , 0.        , ..., 0.29099244, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3467917 , 0.        , 0.        , ..., 0.30231673, 0.        ,
#          0.        ],
#         [1.3344948 , 0.        , 0.        , ..., 0.28788352, 0.        ,
#          0.        ],
#         [1.3659494 , 0.        , 0.        , ..., 0.31200492, 0.        ,
#          0.        ],
#         ...,
#         [1.3434657 , 0.        , 0.        , ..., 0.30480075, 0.        ,
#          0.        ],
#         [1.3484508 , 0.        , 0.        , ..., 0.33560774, 0.        ,
#          0.        ],
#         [1.3316535 , 0.        , 0.        , ..., 0.29477942, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3326542 , 0.        , 0.        , ..., 0.29192805, 0.        ,
#          0.        ],
#         [1.3452237 , 0.        , 0.        , ..., 0.30621678, 0.        ,
#          0.        ],
#         [1.367938  , 0.        , 0.        , ..., 0.3180201 , 0.        ,
#          0.        ],
#         ...,
#         [1.3340585 , 0.        , 0.        , ..., 0.289658  , 0.        ,
#          0.        ],
#         [1.3648635 , 0.        , 0.        , ..., 0.31004283, 0.        ,
#          0.        ],
#         [1.3560879 , 0.        , 0.        , ..., 0.32256377, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3411608 , 0.        , 0.        , ..., 0.3140086 , 0.        ,
#          0.        ],
#         [1.3433628 , 0.        , 0.        , ..., 0.2964259 , 0.        ,
#          0.        ],
#         [1.3504903 , 0.        , 0.        , ..., 0.29574686, 0.        ,
#          0.        ],
#         ...,
#         [1.3397574 , 0.        , 0.        , ..., 0.29506487, 0.        ,
#          0.        ],
#         [1.3346043 , 0.        , 0.        , ..., 0.2897492 , 0.        ,
#          0.        ],
#         [1.360115  , 0.        , 0.        , ..., 0.33741376, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3471314 , 0.        , 0.        , ..., 0.31792346, 0.        ,
#          0.        ],
#         [1.3342735 , 0.        , 0.        , ..., 0.2797991 , 0.        ,
#          0.        ],
#         [1.3364506 , 0.        , 0.        , ..., 0.29853523, 0.        ,
#          0.        ],
#         ...,
#         [1.3313603 , 0.        , 0.        , ..., 0.28300917, 0.        ,
#          0.        ],
#         [1.349594  , 0.        , 0.        , ..., 0.305538  , 0.        ,
#          0.        ],
#         [1.3326174 , 0.        , 0.        , ..., 0.28198266, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3491727 , 0.        , 0.        , ..., 0.31076404, 0.        ,
#          0.        ],
#         [1.3369596 , 0.        , 0.        , ..., 0.28432265, 0.        ,
#          0.        ],
#         [1.3486594 , 0.        , 0.        , ..., 0.3420458 , 0.        ,
#          0.        ],
#         ...,
#         [1.338892  , 0.        , 0.        , ..., 0.2756032 , 0.        ,
#          0.        ],
#         [1.3307914 , 0.        , 0.        , ..., 0.28510326, 0.        ,
#          0.        ],
#         [1.3386302 , 0.        , 0.        , ..., 0.31331256, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3407769 , 0.        , 0.        , ..., 0.28506327, 0.        ,
#          0.        ],
#         [1.3627263 , 0.        , 0.        , ..., 0.30895397, 0.        ,
#          0.        ],
#         [1.3403852 , 0.        , 0.        , ..., 0.29168504, 0.        ,
#          0.        ],
#         ...,
#         [1.3405185 , 0.        , 0.        , ..., 0.28754944, 0.        ,
#          0.        ],
#         [1.3485018 , 0.        , 0.        , ..., 0.33486015, 0.        ,
#          0.        ],
#         [1.3235936 , 0.        , 0.        , ..., 0.31550604, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.347012  , 0.        , 0.        , ..., 0.3112997 , 0.        ,
#          0.        ],
#         [1.3288269 , 0.        , 0.        , ..., 0.29111823, 0.        ,
#          0.        ],
#         [1.3462133 , 0.        , 0.        , ..., 0.3057623 , 0.        ,
#          0.        ],
#         ...,
#         [1.335459  , 0.        , 0.        , ..., 0.28383774, 0.        ,
#          0.        ],
#         [1.333609  , 0.        , 0.        , ..., 0.28212315, 0.        ,
#          0.        ],
#         [1.3429784 , 0.        , 0.        , ..., 0.3391386 , 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3386636e+00, 0.0000000e+00, 0.0000000e+00, ..., 2.9560670e-01,
#          9.5899217e-04, 0.0000000e+00],
#         [1.3352768e+00, 0.0000000e+00, 0.0000000e+00, ..., 2.9178810e-01,
#          0.0000000e+00, 0.0000000e+00],
#         [1.3391349e+00, 0.0000000e+00, 0.0000000e+00, ..., 3.1675047e-01,
#          0.0000000e+00, 0.0000000e+00],
#         ...,
#         [1.3763690e+00, 0.0000000e+00, 0.0000000e+00, ..., 3.1282285e-01,
#          0.0000000e+00, 0.0000000e+00],
#         [1.3347669e+00, 0.0000000e+00, 0.0000000e+00, ..., 2.9174325e-01,
#          0.0000000e+00, 0.0000000e+00],
#         [1.3333347e+00, 0.0000000e+00, 0.0000000e+00, ..., 3.1386781e-01,
#          0.0000000e+00, 0.0000000e+00]], dtype=float32),
#  array([[1.3352238 , 0.        , 0.        , ..., 0.2890796 , 0.        ,
#          0.        ],
#         [1.3335353 , 0.        , 0.        , ..., 0.29920858, 0.        ,
#          0.        ],
#         [1.3318443 , 0.        , 0.        , ..., 0.27794   , 0.        ,
#          0.        ],
#         ...,
#         [1.3299208 , 0.        , 0.        , ..., 0.28135148, 0.        ,
#          0.        ],
#         [1.3506534 , 0.00310389, 0.        , ..., 0.29370636, 0.        ,
#          0.        ],
#         [1.3371967 , 0.        , 0.        , ..., 0.2865473 , 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3354143 , 0.        , 0.        , ..., 0.2827596 , 0.        ,
#          0.        ],
#         [1.3437698 , 0.        , 0.        , ..., 0.30036473, 0.        ,
#          0.        ],
#         [1.3335537 , 0.        , 0.        , ..., 0.27792358, 0.        ,
#          0.        ],
#         ...,
#         [1.3345268 , 0.        , 0.        , ..., 0.28558704, 0.        ,
#          0.        ],
#         [1.3508133 , 0.        , 0.        , ..., 0.30492505, 0.        ,
#          0.        ],
#         [1.3333123 , 0.        , 0.        , ..., 0.29496586, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3437191 , 0.        , 0.        , ..., 0.2932889 , 0.        ,
#          0.        ],
#         [1.3642092 , 0.        , 0.        , ..., 0.3352415 , 0.        ,
#          0.        ],
#         [1.3242006 , 0.        , 0.        , ..., 0.29892832, 0.        ,
#          0.        ],
#         ...,
#         [1.3239783 , 0.        , 0.        , ..., 0.28769973, 0.        ,
#          0.        ],
#         [1.3460813 , 0.        , 0.        , ..., 0.32472605, 0.        ,
#          0.        ],
#         [1.3331465 , 0.        , 0.        , ..., 0.2921908 , 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3421593 , 0.        , 0.        , ..., 0.2921047 , 0.        ,
#          0.        ],
#         [1.3425996 , 0.        , 0.        , ..., 0.31037065, 0.        ,
#          0.        ],
#         [1.3343673 , 0.        , 0.        , ..., 0.29561326, 0.        ,
#          0.        ],
#         ...,
#         [1.3487403 , 0.        , 0.        , ..., 0.3198161 , 0.        ,
#          0.        ],
#         [1.3409492 , 0.        , 0.        , ..., 0.2879816 , 0.        ,
#          0.        ],
#         [1.3506455 , 0.        , 0.        , ..., 0.31792074, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3323754 , 0.        , 0.        , ..., 0.29450372, 0.        ,
#          0.        ],
#         [1.3404504 , 0.        , 0.        , ..., 0.3247332 , 0.        ,
#          0.        ],
#         [1.3377709 , 0.        , 0.        , ..., 0.29266948, 0.        ,
#          0.        ],
#         ...,
#         [1.3385142 , 0.        , 0.        , ..., 0.2880004 , 0.        ,
#          0.        ],
#         [1.365298  , 0.        , 0.        , ..., 0.3141042 , 0.        ,
#          0.        ],
#         [1.3703296 , 0.        , 0.        , ..., 0.32502663, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3557262 , 0.        , 0.        , ..., 0.3195975 , 0.        ,
#          0.        ],
#         [1.3425956 , 0.        , 0.        , ..., 0.3146771 , 0.        ,
#          0.        ],
#         [1.3313055 , 0.        , 0.        , ..., 0.27744037, 0.        ,
#          0.        ],
#         ...,
#         [1.3489354 , 0.        , 0.        , ..., 0.31439823, 0.        ,
#          0.        ],
#         [1.3396981 , 0.        , 0.        , ..., 0.28795668, 0.        ,
#          0.        ],
#         [1.3484713 , 0.        , 0.        , ..., 0.31887737, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3392491 , 0.        , 0.        , ..., 0.3010921 , 0.        ,
#          0.        ],
#         [1.3577281 , 0.        , 0.        , ..., 0.31766224, 0.        ,
#          0.        ],
#         [1.3333083 , 0.        , 0.        , ..., 0.27992496, 0.        ,
#          0.        ],
#         ...,
#         [1.3325531 , 0.        , 0.        , ..., 0.2761104 , 0.        ,
#          0.        ],
#         [1.3793896 , 0.        , 0.        , ..., 0.2991826 , 0.02998492,
#          0.        ],
#         [1.3306396 , 0.        , 0.        , ..., 0.28569806, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3375692 , 0.        , 0.        , ..., 0.3140535 , 0.        ,
#          0.        ],
#         [1.341686  , 0.        , 0.        , ..., 0.3090768 , 0.        ,
#          0.        ],
#         [1.3364501 , 0.        , 0.        , ..., 0.31382978, 0.        ,
#          0.        ],
#         ...,
#         [1.3673713 , 0.        , 0.        , ..., 0.29380146, 0.        ,
#          0.        ],
#         [1.345713  , 0.        , 0.        , ..., 0.28729796, 0.        ,
#          0.        ],
#         [1.3456479 , 0.        , 0.        , ..., 0.29748535, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3441176 , 0.        , 0.        , ..., 0.32003382, 0.        ,
#          0.        ],
#         [1.3487178 , 0.        , 0.        , ..., 0.3174507 , 0.        ,
#          0.        ],
#         [1.3320489 , 0.        , 0.        , ..., 0.27662408, 0.        ,
#          0.        ],
#         ...,
#         [1.3271692 , 0.        , 0.        , ..., 0.28650308, 0.        ,
#          0.        ],
#         [1.3379909 , 0.        , 0.        , ..., 0.31342036, 0.        ,
#          0.        ],
#         [1.3480964 , 0.        , 0.        , ..., 0.301041  , 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3339622 , 0.        , 0.        , ..., 0.28323972, 0.        ,
#          0.        ],
#         [1.3395457 , 0.        , 0.        , ..., 0.29904932, 0.        ,
#          0.        ],
#         [1.3449087 , 0.        , 0.        , ..., 0.2860237 , 0.        ,
#          0.        ],
#         ...,
#         [1.3356657 , 0.        , 0.        , ..., 0.28552124, 0.        ,
#          0.        ],
#         [1.3390312 , 0.        , 0.        , ..., 0.29898858, 0.        ,
#          0.        ],
#         [1.3546762 , 0.        , 0.        , ..., 0.30886728, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3309795 , 0.        , 0.        , ..., 0.28318572, 0.        ,
#          0.        ],
#         [1.3315337 , 0.        , 0.        , ..., 0.28499043, 0.        ,
#          0.        ],
#         [1.370597  , 0.        , 0.        , ..., 0.3102575 , 0.02607191,
#          0.        ],
#         ...,
#         [1.3569231 , 0.        , 0.        , ..., 0.32223594, 0.        ,
#          0.        ],
#         [1.3359718 , 0.        , 0.        , ..., 0.29029524, 0.        ,
#          0.        ],
#         [1.3323629 , 0.        , 0.        , ..., 0.29258567, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3422670e+00, 0.0000000e+00, 0.0000000e+00, ..., 2.9349309e-01,
#          0.0000000e+00, 0.0000000e+00],
#         [1.3330966e+00, 0.0000000e+00, 0.0000000e+00, ..., 3.0556455e-01,
#          0.0000000e+00, 0.0000000e+00],
#         [1.3577330e+00, 0.0000000e+00, 0.0000000e+00, ..., 3.1728810e-01,
#          4.3834746e-04, 0.0000000e+00],
#         ...,
#         [1.3304158e+00, 0.0000000e+00, 0.0000000e+00, ..., 2.8679967e-01,
#          0.0000000e+00, 0.0000000e+00],
#         [1.3324726e+00, 0.0000000e+00, 0.0000000e+00, ..., 2.8415281e-01,
#          0.0000000e+00, 0.0000000e+00],
#         [1.3591920e+00, 0.0000000e+00, 0.0000000e+00, ..., 2.9777682e-01,
#          0.0000000e+00, 0.0000000e+00]], dtype=float32),
#  array([[1.3487072 , 0.        , 0.        , ..., 0.3462392 , 0.        ,
#          0.        ],
#         [1.3662114 , 0.        , 0.        , ..., 0.32616264, 0.        ,
#          0.        ],
#         [1.332155  , 0.        , 0.        , ..., 0.28514656, 0.        ,
#          0.        ],
#         ...,
#         [1.3378432 , 0.        , 0.        , ..., 0.29725215, 0.        ,
#          0.        ],
#         [1.3582245 , 0.        , 0.        , ..., 0.3311344 , 0.        ,
#          0.        ],
#         [1.3296273 , 0.        , 0.        , ..., 0.2817046 , 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3393035 , 0.        , 0.        , ..., 0.29370192, 0.        ,
#          0.        ],
#         [1.3383896 , 0.        , 0.        , ..., 0.3061347 , 0.        ,
#          0.        ],
#         [1.3453492 , 0.        , 0.        , ..., 0.29070103, 0.        ,
#          0.        ],
#         ...,
#         [1.3332815 , 0.        , 0.        , ..., 0.2932444 , 0.        ,
#          0.        ],
#         [1.3291543 , 0.        , 0.        , ..., 0.28210768, 0.        ,
#          0.        ],
#         [1.3356895 , 0.        , 0.        , ..., 0.31120682, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3462057 , 0.        , 0.        , ..., 0.2882092 , 0.        ,
#          0.        ],
#         [1.333528  , 0.        , 0.        , ..., 0.2843325 , 0.        ,
#          0.        ],
#         [1.3348634 , 0.        , 0.        , ..., 0.28701186, 0.        ,
#          0.        ],
#         ...,
#         [1.3321563 , 0.        , 0.        , ..., 0.29135135, 0.        ,
#          0.        ],
#         [1.3837687 , 0.        , 0.        , ..., 0.30175894, 0.        ,
#          0.        ],
#         [1.3330104 , 0.        , 0.        , ..., 0.2859363 , 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3442186 , 0.        , 0.        , ..., 0.30428225, 0.        ,
#          0.        ],
#         [1.3530359 , 0.        , 0.        , ..., 0.32606873, 0.        ,
#          0.        ],
#         [1.343296  , 0.        , 0.        , ..., 0.29841018, 0.        ,
#          0.        ],
#         ...,
#         [1.3348308 , 0.        , 0.        , ..., 0.28069478, 0.        ,
#          0.        ],
#         [1.3507744 , 0.        , 0.        , ..., 0.28752285, 0.        ,
#          0.        ],
#         [1.3412158 , 0.        , 0.        , ..., 0.327304  , 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3496011 , 0.        , 0.        , ..., 0.3201397 , 0.        ,
#          0.        ],
#         [1.3308079 , 0.        , 0.        , ..., 0.28567135, 0.        ,
#          0.        ],
#         [1.3298743 , 0.        , 0.        , ..., 0.28947884, 0.        ,
#          0.        ],
#         ...,
#         [1.3544233 , 0.        , 0.        , ..., 0.31832504, 0.        ,
#          0.        ],
#         [1.3314166 , 0.        , 0.        , ..., 0.31212103, 0.        ,
#          0.        ],
#         [1.3409873 , 0.        , 0.        , ..., 0.28586367, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3536793 , 0.        , 0.        , ..., 0.3237297 , 0.        ,
#          0.        ],
#         [1.3380399 , 0.        , 0.        , ..., 0.28559262, 0.        ,
#          0.        ],
#         [1.3359926 , 0.        , 0.        , ..., 0.2910109 , 0.        ,
#          0.        ],
#         ...,
#         [1.3373687 , 0.        , 0.        , ..., 0.29332748, 0.        ,
#          0.        ],
#         [1.33175   , 0.        , 0.        , ..., 0.27513036, 0.        ,
#          0.        ],
#         [1.3317125 , 0.        , 0.        , ..., 0.29861337, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3434935 , 0.        , 0.        , ..., 0.3132097 , 0.        ,
#          0.        ],
#         [1.3376007 , 0.        , 0.        , ..., 0.3047239 , 0.        ,
#          0.        ],
#         [1.3446963 , 0.        , 0.        , ..., 0.2939301 , 0.        ,
#          0.        ],
#         ...,
#         [1.3378406 , 0.        , 0.        , ..., 0.30604148, 0.        ,
#          0.        ],
#         [1.3472931 , 0.        , 0.        , ..., 0.29050556, 0.        ,
#          0.        ],
#         [1.3496494 , 0.        , 0.        , ..., 0.32852393, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3361902 , 0.        , 0.        , ..., 0.34312516, 0.        ,
#          0.        ],
#         [1.3398952 , 0.        , 0.        , ..., 0.29261565, 0.        ,
#          0.        ],
#         [1.3351713 , 0.        , 0.        , ..., 0.28908166, 0.        ,
#          0.        ],
#         ...,
#         [1.3359249 , 0.        , 0.        , ..., 0.30610377, 0.        ,
#          0.        ],
#         [1.3394884 , 0.        , 0.        , ..., 0.28422773, 0.        ,
#          0.        ],
#         [1.3362865 , 0.        , 0.        , ..., 0.28703994, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3315028 , 0.        , 0.        , ..., 0.27837226, 0.        ,
#          0.        ],
#         [1.3502675 , 0.        , 0.        , ..., 0.30828905, 0.        ,
#          0.        ],
#         [1.3326656 , 0.        , 0.        , ..., 0.2841047 , 0.        ,
#          0.        ],
#         ...,
#         [1.3366604 , 0.        , 0.        , ..., 0.3129431 , 0.        ,
#          0.        ],
#         [1.3467045 , 0.        , 0.        , ..., 0.32609218, 0.        ,
#          0.        ],
#         [1.3565074 , 0.        , 0.        , ..., 0.3081448 , 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3297627, 0.       , 0.       , ..., 0.2874958, 0.       ,
#          0.       ],
#         [1.3532957, 0.       , 0.       , ..., 0.3212579, 0.       ,
#          0.       ],
#         [1.3338375, 0.       , 0.       , ..., 0.2911076, 0.       ,
#          0.       ],
#         ...,
#         [1.3304563, 0.       , 0.       , ..., 0.2823494, 0.       ,
#          0.       ],
#         [1.3380281, 0.       , 0.       , ..., 0.3312229, 0.       ,
#          0.       ],
#         [1.34932  , 0.       , 0.       , ..., 0.2976128, 0.       ,
#          0.       ]], dtype=float32),
#  array([[1.345697  , 0.        , 0.        , ..., 0.28777206, 0.        ,
#          0.        ],
#         [1.3296404 , 0.        , 0.        , ..., 0.2871744 , 0.        ,
#          0.        ],
#         [1.3352749 , 0.        , 0.        , ..., 0.28641367, 0.        ,
#          0.        ],
#         ...,
#         [1.3439797 , 0.        , 0.        , ..., 0.28906074, 0.        ,
#          0.        ],
#         [1.3506303 , 0.        , 0.        , ..., 0.30390632, 0.        ,
#          0.        ],
#         [1.3388902 , 0.        , 0.        , ..., 0.31363463, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3452051 , 0.        , 0.        , ..., 0.31192437, 0.        ,
#          0.        ],
#         [1.3576314 , 0.        , 0.        , ..., 0.2899329 , 0.        ,
#          0.        ],
#         [1.3317912 , 0.        , 0.        , ..., 0.29352438, 0.        ,
#          0.        ],
#         ...,
#         [1.3400886 , 0.        , 0.        , ..., 0.31753403, 0.        ,
#          0.        ],
#         [1.3405463 , 0.        , 0.        , ..., 0.28523   , 0.        ,
#          0.        ],
#         [1.3365911 , 0.        , 0.        , ..., 0.2880262 , 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3358743 , 0.        , 0.        , ..., 0.28363222, 0.        ,
#          0.        ],
#         [1.3380305 , 0.        , 0.        , ..., 0.3053776 , 0.        ,
#          0.        ],
#         [1.325916  , 0.        , 0.        , ..., 0.28978217, 0.        ,
#          0.        ],
#         ...,
#         [1.3315253 , 0.        , 0.        , ..., 0.29189333, 0.        ,
#          0.        ],
#         [1.3377128 , 0.        , 0.        , ..., 0.29473573, 0.        ,
#          0.        ],
#         [1.3436399 , 0.        , 0.        , ..., 0.31827596, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3430979 , 0.        , 0.        , ..., 0.30499288, 0.        ,
#          0.        ],
#         [1.3422332 , 0.        , 0.        , ..., 0.29835966, 0.        ,
#          0.        ],
#         [1.3651453 , 0.        , 0.        , ..., 0.3309862 , 0.        ,
#          0.        ],
#         ...,
#         [1.3653288 , 0.        , 0.        , ..., 0.29646719, 0.        ,
#          0.        ],
#         [1.3503225 , 0.        , 0.        , ..., 0.33042127, 0.        ,
#          0.        ],
#         [1.3311557 , 0.        , 0.        , ..., 0.28521103, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3556182 , 0.        , 0.        , ..., 0.31393313, 0.        ,
#          0.        ],
#         [1.333087  , 0.        , 0.        , ..., 0.29047722, 0.        ,
#          0.        ],
#         [1.3620328 , 0.        , 0.        , ..., 0.31258792, 0.        ,
#          0.        ],
#         ...,
#         [1.3493953 , 0.        , 0.        , ..., 0.33954924, 0.        ,
#          0.        ],
#         [1.3427708 , 0.        , 0.        , ..., 0.28943956, 0.        ,
#          0.        ],
#         [1.3347635 , 0.        , 0.        , ..., 0.30135334, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.345024  , 0.        , 0.        , ..., 0.29026362, 0.        ,
#          0.        ],
#         [1.3433077 , 0.        , 0.        , ..., 0.30371797, 0.        ,
#          0.        ],
#         [1.3375835 , 0.        , 0.        , ..., 0.2949976 , 0.        ,
#          0.        ],
#         ...,
#         [1.3448007 , 0.        , 0.        , ..., 0.33116126, 0.        ,
#          0.        ],
#         [1.3361572 , 0.        , 0.        , ..., 0.30796432, 0.        ,
#          0.        ],
#         [1.3372812 , 0.        , 0.        , ..., 0.2803973 , 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3382388e+00, 8.0848485e-04, 0.0000000e+00, ..., 2.8641334e-01,
#          1.1441521e-02, 0.0000000e+00],
#         [1.3688581e+00, 0.0000000e+00, 0.0000000e+00, ..., 3.0550438e-01,
#          0.0000000e+00, 0.0000000e+00],
#         [1.3335743e+00, 0.0000000e+00, 0.0000000e+00, ..., 2.9293495e-01,
#          0.0000000e+00, 0.0000000e+00],
#         ...,
#         [1.3557062e+00, 0.0000000e+00, 0.0000000e+00, ..., 3.0486527e-01,
#          0.0000000e+00, 0.0000000e+00],
#         [1.3360645e+00, 0.0000000e+00, 0.0000000e+00, ..., 3.1703484e-01,
#          0.0000000e+00, 0.0000000e+00],
#         [1.3348122e+00, 0.0000000e+00, 0.0000000e+00, ..., 2.8823036e-01,
#          0.0000000e+00, 0.0000000e+00]], dtype=float32),
#  array([[1.3366177 , 0.        , 0.        , ..., 0.30241686, 0.        ,
#          0.        ],
#         [1.3420213 , 0.        , 0.        , ..., 0.3030399 , 0.        ,
#          0.        ],
#         [1.3597444 , 0.        , 0.        , ..., 0.3072818 , 0.        ,
#          0.        ],
#         ...,
#         [1.3398263 , 0.        , 0.        , ..., 0.32850158, 0.        ,
#          0.        ],
#         [1.3454559 , 0.        , 0.        , ..., 0.28409374, 0.        ,
#          0.        ],
#         [1.3760103 , 0.        , 0.        , ..., 0.29093122, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3457497 , 0.        , 0.        , ..., 0.2883839 , 0.        ,
#          0.        ],
#         [1.3283328 , 0.        , 0.        , ..., 0.31723094, 0.        ,
#          0.        ],
#         [1.3487337 , 0.        , 0.        , ..., 0.2924834 , 0.        ,
#          0.        ],
#         ...,
#         [1.3474078 , 0.        , 0.        , ..., 0.2966627 , 0.        ,
#          0.        ],
#         [1.3386827 , 0.        , 0.        , ..., 0.292275  , 0.        ,
#          0.        ],
#         [1.3560679 , 0.        , 0.        , ..., 0.348141  , 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3297334 , 0.        , 0.        , ..., 0.2822893 , 0.        ,
#          0.        ],
#         [1.3667593 , 0.        , 0.        , ..., 0.33039835, 0.        ,
#          0.        ],
#         [1.3615043 , 0.        , 0.        , ..., 0.3122765 , 0.        ,
#          0.        ],
#         ...,
#         [1.3391087 , 0.        , 0.        , ..., 0.28775734, 0.        ,
#          0.        ],
#         [1.3427757 , 0.        , 0.        , ..., 0.31654263, 0.        ,
#          0.        ],
#         [1.3457861 , 0.        , 0.        , ..., 0.3407895 , 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3347647 , 0.        , 0.        , ..., 0.2878983 , 0.        ,
#          0.        ],
#         [1.3464208 , 0.        , 0.        , ..., 0.33725196, 0.        ,
#          0.        ],
#         [1.3280392 , 0.        , 0.        , ..., 0.27915335, 0.        ,
#          0.        ],
#         ...,
#         [1.3355794 , 0.        , 0.        , ..., 0.33980274, 0.        ,
#          0.        ],
#         [1.34167   , 0.        , 0.        , ..., 0.31068683, 0.        ,
#          0.        ],
#         [1.3429797 , 0.        , 0.        , ..., 0.29235923, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3385803 , 0.        , 0.        , ..., 0.2879658 , 0.        ,
#          0.        ],
#         [1.3392141 , 0.        , 0.        , ..., 0.29502946, 0.        ,
#          0.        ],
#         [1.3391311 , 0.        , 0.        , ..., 0.32210904, 0.        ,
#          0.        ],
#         ...,
#         [1.3386086 , 0.        , 0.        , ..., 0.2978617 , 0.        ,
#          0.        ],
#         [1.3788754 , 0.        , 0.        , ..., 0.310324  , 0.        ,
#          0.        ],
#         [1.3416004 , 0.        , 0.        , ..., 0.31093746, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3306999 , 0.        , 0.        , ..., 0.28912008, 0.        ,
#          0.        ],
#         [1.3357863 , 0.        , 0.        , ..., 0.27875763, 0.        ,
#          0.        ],
#         [1.3490756 , 0.        , 0.        , ..., 0.34557718, 0.        ,
#          0.        ],
#         ...,
#         [1.341727  , 0.        , 0.        , ..., 0.31219685, 0.        ,
#          0.        ],
#         [1.337745  , 0.        , 0.        , ..., 0.3290444 , 0.        ,
#          0.        ],
#         [1.3459122 , 0.        , 0.        , ..., 0.30803928, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3408821 , 0.        , 0.        , ..., 0.28957444, 0.        ,
#          0.        ],
#         [1.3379605 , 0.        , 0.        , ..., 0.2906775 , 0.        ,
#          0.        ],
#         [1.3380092 , 0.        , 0.        , ..., 0.2944963 , 0.        ,
#          0.        ],
#         ...,
#         [1.3510787 , 0.        , 0.        , ..., 0.3080699 , 0.        ,
#          0.        ],
#         [1.3333511 , 0.        , 0.        , ..., 0.28518462, 0.        ,
#          0.        ],
#         [1.3291612 , 0.        , 0.        , ..., 0.2873981 , 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3408659 , 0.        , 0.        , ..., 0.32999864, 0.        ,
#          0.        ],
#         [1.3323374 , 0.        , 0.        , ..., 0.27925184, 0.        ,
#          0.        ],
#         [1.3350232 , 0.        , 0.        , ..., 0.28659594, 0.        ,
#          0.        ],
#         ...,
#         [1.3306153 , 0.        , 0.        , ..., 0.28646356, 0.        ,
#          0.        ],
#         [1.3443453 , 0.        , 0.        , ..., 0.3001728 , 0.        ,
#          0.        ],
#         [1.3335986 , 0.        , 0.        , ..., 0.28105482, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3342144 , 0.        , 0.        , ..., 0.29230338, 0.        ,
#          0.        ],
#         [1.3496974 , 0.        , 0.        , ..., 0.3097729 , 0.        ,
#          0.        ],
#         [1.3306129 , 0.        , 0.        , ..., 0.29888734, 0.        ,
#          0.        ],
#         ...,
#         [1.3393962 , 0.        , 0.        , ..., 0.28688446, 0.        ,
#          0.        ],
#         [1.3338544 , 0.        , 0.        , ..., 0.2828179 , 0.        ,
#          0.        ],
#         [1.3402103 , 0.        , 0.        , ..., 0.28800035, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3426507 , 0.        , 0.        , ..., 0.29197526, 0.        ,
#          0.        ],
#         [1.3394895 , 0.        , 0.        , ..., 0.2859545 , 0.        ,
#          0.        ],
#         [1.3333182 , 0.        , 0.        , ..., 0.29170817, 0.        ,
#          0.        ],
#         ...,
#         [1.3573554 , 0.        , 0.        , ..., 0.30231982, 0.        ,
#          0.        ],
#         [1.3639278 , 0.        , 0.        , ..., 0.34076625, 0.        ,
#          0.        ],
#         [1.343434  , 0.        , 0.        , ..., 0.32309496, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3475718 , 0.        , 0.        , ..., 0.32867247, 0.        ,
#          0.        ],
#         [1.3458406 , 0.        , 0.        , ..., 0.29168975, 0.        ,
#          0.        ],
#         [1.3398411 , 0.        , 0.        , ..., 0.2980402 , 0.        ,
#          0.        ],
#         ...,
#         [1.3533843 , 0.        , 0.        , ..., 0.3074594 , 0.        ,
#          0.        ],
#         [1.3322712 , 0.        , 0.        , ..., 0.33500946, 0.        ,
#          0.        ],
#         [1.334255  , 0.        , 0.        , ..., 0.28481627, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3479009 , 0.        , 0.        , ..., 0.32384855, 0.        ,
#          0.        ],
#         [1.3372018 , 0.        , 0.        , ..., 0.30916613, 0.        ,
#          0.        ],
#         [1.3408391 , 0.        , 0.        , ..., 0.3054766 , 0.        ,
#          0.        ],
#         ...,
#         [1.3600568 , 0.        , 0.        , ..., 0.31023785, 0.        ,
#          0.        ],
#         [1.3365533 , 0.        , 0.        , ..., 0.28643942, 0.        ,
#          0.        ],
#         [1.3512282 , 0.        , 0.        , ..., 0.30443347, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3315241 , 0.        , 0.        , ..., 0.29834527, 0.        ,
#          0.        ],
#         [1.3384552 , 0.        , 0.        , ..., 0.32871464, 0.        ,
#          0.        ],
#         [1.3473825 , 0.        , 0.        , ..., 0.31997478, 0.        ,
#          0.        ],
#         ...,
#         [1.3387907 , 0.        , 0.        , ..., 0.3064081 , 0.        ,
#          0.        ],
#         [1.3398345 , 0.        , 0.        , ..., 0.3081568 , 0.        ,
#          0.        ],
#         [1.3419623 , 0.        , 0.        , ..., 0.292072  , 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3447168 , 0.        , 0.        , ..., 0.30593276, 0.        ,
#          0.        ],
#         [1.3401614 , 0.        , 0.        , ..., 0.28791583, 0.        ,
#          0.        ],
#         [1.3506706 , 0.        , 0.        , ..., 0.33976173, 0.        ,
#          0.        ],
#         ...,
#         [1.3381243 , 0.        , 0.        , ..., 0.29119334, 0.        ,
#          0.        ],
#         [1.3415188 , 0.        , 0.        , ..., 0.28509346, 0.        ,
#          0.        ],
#         [1.3348353 , 0.        , 0.        , ..., 0.30574065, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3705859 , 0.        , 0.        , ..., 0.3014198 , 0.        ,
#          0.        ],
#         [1.3430154 , 0.        , 0.        , ..., 0.29828572, 0.        ,
#          0.        ],
#         [1.3356152 , 0.        , 0.        , ..., 0.28801197, 0.        ,
#          0.        ],
#         ...,
#         [1.3405354 , 0.        , 0.        , ..., 0.31702822, 0.        ,
#          0.        ],
#         [1.3484015 , 0.        , 0.        , ..., 0.31903195, 0.        ,
#          0.        ],
#         [1.3419918 , 0.        , 0.        , ..., 0.29408306, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3747494 , 0.        , 0.        , ..., 0.3171839 , 0.        ,
#          0.        ],
#         [1.3458414 , 0.        , 0.        , ..., 0.3157524 , 0.        ,
#          0.        ],
#         [1.3327699 , 0.        , 0.        , ..., 0.28443834, 0.        ,
#          0.        ],
#         ...,
#         [1.3651049 , 0.        , 0.        , ..., 0.3205256 , 0.        ,
#          0.        ],
#         [1.3318915 , 0.        , 0.        , ..., 0.28273863, 0.        ,
#          0.        ],
#         [1.3661106 , 0.        , 0.        , ..., 0.31858927, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.364466  , 0.        , 0.        , ..., 0.3141904 , 0.        ,
#          0.        ],
#         [1.3324242 , 0.        , 0.        , ..., 0.28461808, 0.        ,
#          0.        ],
#         [1.3953618 , 0.        , 0.        , ..., 0.30262375, 0.00709924,
#          0.        ],
#         ...,
#         [1.3394486 , 0.        , 0.        , ..., 0.31188548, 0.        ,
#          0.        ],
#         [1.3526278 , 0.        , 0.        , ..., 0.34197223, 0.        ,
#          0.        ],
#         [1.3501638 , 0.        , 0.        , ..., 0.31899828, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.344765  , 0.        , 0.        , ..., 0.2993262 , 0.        ,
#          0.        ],
#         [1.3388785 , 0.        , 0.        , ..., 0.29567015, 0.        ,
#          0.        ],
#         [1.3686843 , 0.        , 0.        , ..., 0.29368508, 0.        ,
#          0.        ],
#         ...,
#         [1.3399799 , 0.        , 0.        , ..., 0.3153256 , 0.        ,
#          0.        ],
#         [1.3339576 , 0.        , 0.        , ..., 0.28674024, 0.        ,
#          0.        ],
#         [1.340574  , 0.        , 0.        , ..., 0.29249623, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3441888 , 0.        , 0.        , ..., 0.3106439 , 0.        ,
#          0.        ],
#         [1.3333254 , 0.        , 0.        , ..., 0.29776877, 0.        ,
#          0.        ],
#         [1.343183  , 0.        , 0.        , ..., 0.31418574, 0.        ,
#          0.        ],
#         ...,
#         [1.332859  , 0.        , 0.        , ..., 0.28024906, 0.        ,
#          0.        ],
#         [1.3338237 , 0.        , 0.        , ..., 0.28420386, 0.        ,
#          0.        ],
#         [1.3331022 , 0.        , 0.        , ..., 0.29163867, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.329842  , 0.        , 0.        , ..., 0.28822237, 0.        ,
#          0.        ],
#         [1.3320285 , 0.        , 0.        , ..., 0.27209342, 0.        ,
#          0.        ],
#         [1.3645467 , 0.        , 0.        , ..., 0.33298874, 0.        ,
#          0.        ],
#         ...,
#         [1.3311019 , 0.        , 0.        , ..., 0.28793043, 0.        ,
#          0.        ],
#         [1.3366933 , 0.        , 0.        , ..., 0.33827376, 0.        ,
#          0.        ],
#         [1.3519793 , 0.        , 0.        , ..., 0.3357538 , 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3329103 , 0.        , 0.        , ..., 0.288119  , 0.        ,
#          0.        ],
#         [1.3561094 , 0.        , 0.        , ..., 0.3142028 , 0.        ,
#          0.        ],
#         [1.347174  , 0.        , 0.        , ..., 0.30631748, 0.        ,
#          0.        ],
#         ...,
#         [1.3493125 , 0.        , 0.        , ..., 0.3061657 , 0.        ,
#          0.        ],
#         [1.3371389 , 0.        , 0.        , ..., 0.29856604, 0.        ,
#          0.        ],
#         [1.3366398 , 0.        , 0.        , ..., 0.30353194, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.358513  , 0.        , 0.        , ..., 0.29842195, 0.        ,
#          0.        ],
#         [1.3382363 , 0.        , 0.        , ..., 0.29031792, 0.        ,
#          0.        ],
#         [1.3312972 , 0.        , 0.        , ..., 0.2827668 , 0.        ,
#          0.        ],
#         ...,
#         [1.329419  , 0.        , 0.        , ..., 0.28226566, 0.        ,
#          0.        ],
#         [1.336359  , 0.        , 0.        , ..., 0.33723462, 0.        ,
#          0.        ],
#         [1.3360326 , 0.        , 0.        , ..., 0.29915977, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3310444 , 0.        , 0.        , ..., 0.2860755 , 0.        ,
#          0.        ],
#         [1.3389515 , 0.        , 0.        , ..., 0.29102808, 0.        ,
#          0.        ],
#         [1.3341448 , 0.        , 0.        , ..., 0.3216073 , 0.        ,
#          0.        ],
#         ...,
#         [1.3907672 , 0.        , 0.        , ..., 0.2863258 , 0.        ,
#          0.        ],
#         [1.3374591 , 0.        , 0.        , ..., 0.3172608 , 0.        ,
#          0.        ],
#         [1.3478214 , 0.        , 0.        , ..., 0.29793656, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3540583 , 0.        , 0.        , ..., 0.29911798, 0.        ,
#          0.        ],
#         [1.3737257 , 0.        , 0.        , ..., 0.3190776 , 0.        ,
#          0.        ],
#         [1.3556461 , 0.        , 0.        , ..., 0.3264091 , 0.        ,
#          0.        ],
#         ...,
#         [1.3494934 , 0.        , 0.        , ..., 0.31606174, 0.        ,
#          0.        ],
#         [1.348283  , 0.        , 0.        , ..., 0.28775936, 0.        ,
#          0.        ],
#         [1.3306702 , 0.        , 0.        , ..., 0.2858358 , 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3318598 , 0.        , 0.        , ..., 0.30767906, 0.        ,
#          0.        ],
#         [1.3550208 , 0.        , 0.        , ..., 0.30392885, 0.        ,
#          0.        ],
#         [1.3351452 , 0.        , 0.        , ..., 0.31660885, 0.        ,
#          0.        ],
#         ...,
#         [1.3335011 , 0.        , 0.        , ..., 0.28032637, 0.        ,
#          0.        ],
#         [1.3454835 , 0.        , 0.        , ..., 0.32873285, 0.        ,
#          0.        ],
#         [1.3308545 , 0.        , 0.        , ..., 0.28727224, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3588413 , 0.        , 0.        , ..., 0.31311062, 0.        ,
#          0.        ],
#         [1.3487377 , 0.        , 0.        , ..., 0.34744012, 0.        ,
#          0.        ],
#         [1.3473873 , 0.        , 0.        , ..., 0.31444225, 0.        ,
#          0.        ],
#         ...,
#         [1.3392053 , 0.        , 0.        , ..., 0.3085399 , 0.        ,
#          0.        ],
#         [1.381017  , 0.        , 0.        , ..., 0.32249248, 0.        ,
#          0.        ],
#         [1.3341012 , 0.        , 0.        , ..., 0.28336096, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3328    , 0.        , 0.        , ..., 0.30346787, 0.        ,
#          0.        ],
#         [1.3350005 , 0.        , 0.        , ..., 0.27583694, 0.        ,
#          0.        ],
#         [1.3496242 , 0.        , 0.        , ..., 0.3159405 , 0.        ,
#          0.        ],
#         ...,
#         [1.3394479 , 0.        , 0.        , ..., 0.32237983, 0.        ,
#          0.        ],
#         [1.3427806 , 0.        , 0.        , ..., 0.2887776 , 0.        ,
#          0.        ],
#         [1.3468618 , 0.        , 0.        , ..., 0.29239127, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3532251 , 0.        , 0.        , ..., 0.3256565 , 0.        ,
#          0.        ],
#         [1.3506484 , 0.        , 0.        , ..., 0.31912625, 0.        ,
#          0.        ],
#         [1.3277057 , 0.        , 0.        , ..., 0.2806781 , 0.        ,
#          0.        ],
#         ...,
#         [1.3585632 , 0.        , 0.        , ..., 0.30525193, 0.        ,
#          0.        ],
#         [1.3583338 , 0.        , 0.        , ..., 0.31465122, 0.        ,
#          0.        ],
#         [1.3465829 , 0.        , 0.        , ..., 0.3200251 , 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3447297 , 0.        , 0.        , ..., 0.31962892, 0.        ,
#          0.        ],
#         [1.3454807 , 0.        , 0.        , ..., 0.3303135 , 0.        ,
#          0.        ],
#         [1.3330605 , 0.        , 0.        , ..., 0.28422853, 0.        ,
#          0.        ],
#         ...,
#         [1.3604926 , 0.        , 0.        , ..., 0.3287248 , 0.        ,
#          0.        ],
#         [1.3505174 , 0.        , 0.        , ..., 0.3175464 , 0.        ,
#          0.        ],
#         [1.3362579 , 0.        , 0.        , ..., 0.28787482, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3394916 , 0.        , 0.        , ..., 0.2976224 , 0.        ,
#          0.        ],
#         [1.3387148 , 0.        , 0.        , ..., 0.2990741 , 0.        ,
#          0.        ],
#         [1.3365119 , 0.        , 0.        , ..., 0.29427576, 0.        ,
#          0.        ],
#         ...,
#         [1.3312452 , 0.        , 0.        , ..., 0.28722322, 0.        ,
#          0.        ],
#         [1.3394825 , 0.        , 0.        , ..., 0.32053572, 0.        ,
#          0.        ],
#         [1.3475308 , 0.        , 0.        , ..., 0.2873494 , 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3341584 , 0.        , 0.        , ..., 0.28730455, 0.        ,
#          0.        ],
#         [1.3501787 , 0.        , 0.        , ..., 0.330425  , 0.        ,
#          0.        ],
#         [1.3442392 , 0.        , 0.        , ..., 0.3102576 , 0.        ,
#          0.        ],
#         ...,
#         [1.3349302 , 0.        , 0.        , ..., 0.29145545, 0.        ,
#          0.        ],
#         [1.3577088 , 0.        , 0.        , ..., 0.29900008, 0.        ,
#          0.        ],
#         [1.3361832 , 0.        , 0.        , ..., 0.30369294, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3300174 , 0.        , 0.        , ..., 0.2835531 , 0.        ,
#          0.        ],
#         [1.3465086 , 0.        , 0.        , ..., 0.34451059, 0.        ,
#          0.        ],
#         [1.3377824 , 0.        , 0.        , ..., 0.28627196, 0.        ,
#          0.        ],
#         ...,
#         [1.3487194 , 0.        , 0.        , ..., 0.29167163, 0.        ,
#          0.        ],
#         [1.3601708 , 0.        , 0.        , ..., 0.3374774 , 0.        ,
#          0.        ],
#         [1.335351  , 0.        , 0.        , ..., 0.29017687, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3331056 , 0.        , 0.        , ..., 0.27583835, 0.        ,
#          0.        ],
#         [1.3447096 , 0.        , 0.        , ..., 0.3382516 , 0.        ,
#          0.        ],
#         [1.3551646 , 0.        , 0.        , ..., 0.32417148, 0.        ,
#          0.        ],
#         ...,
#         [1.3421272 , 0.        , 0.        , ..., 0.298839  , 0.        ,
#          0.        ],
#         [1.3370357 , 0.        , 0.        , ..., 0.2929015 , 0.        ,
#          0.        ],
#         [1.3394103 , 0.        , 0.        , ..., 0.305659  , 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3358831 , 0.        , 0.        , ..., 0.28486896, 0.        ,
#          0.        ],
#         [1.3299593 , 0.        , 0.        , ..., 0.29293406, 0.        ,
#          0.        ],
#         [1.3348277 , 0.        , 0.        , ..., 0.32024387, 0.        ,
#          0.        ],
#         ...,
#         [1.3417052 , 0.        , 0.        , ..., 0.28978294, 0.        ,
#          0.        ],
#         [1.3794072 , 0.        , 0.        , ..., 0.29463   , 0.        ,
#          0.        ],
#         [1.3394268 , 0.        , 0.        , ..., 0.29682693, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3370855 , 0.        , 0.        , ..., 0.30036813, 0.        ,
#          0.        ],
#         [1.347133  , 0.        , 0.        , ..., 0.30209   , 0.        ,
#          0.        ],
#         [1.3349643 , 0.        , 0.        , ..., 0.28733674, 0.        ,
#          0.        ],
#         ...,
#         [1.3335841 , 0.        , 0.        , ..., 0.28994837, 0.        ,
#          0.        ],
#         [1.333513  , 0.        , 0.        , ..., 0.3005122 , 0.        ,
#          0.        ],
#         [1.3489324 , 0.        , 0.        , ..., 0.2928494 , 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.330343  , 0.        , 0.        , ..., 0.2985239 , 0.        ,
#          0.        ],
#         [1.3358736 , 0.        , 0.        , ..., 0.30670735, 0.        ,
#          0.        ],
#         [1.3474317 , 0.        , 0.        , ..., 0.33325687, 0.        ,
#          0.        ],
#         ...,
#         [1.344303  , 0.        , 0.        , ..., 0.31544775, 0.        ,
#          0.        ],
# ...
#         [1.3350009 , 0.        , 0.        , ..., 0.31457824, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3409772 , 0.        , 0.        , ..., 0.33102787, 0.        ,
#          0.        ],
#         [1.3291768 , 0.        , 0.        , ..., 0.28985876, 0.        ,
#          0.        ],
#         [1.3367412 , 0.        , 0.        , ..., 0.29533285, 0.        ,
#          0.        ],
#         ...,
#         [1.3534638 , 0.        , 0.        , ..., 0.29549134, 0.        ,
#          0.        ],
#         [1.3403008 , 0.        , 0.        , ..., 0.29731008, 0.        ,
#          0.        ],
#         [1.3404739 , 0.        , 0.        , ..., 0.33069068, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3581934 , 0.        , 0.        , ..., 0.3056763 , 0.        ,
#          0.        ],
#         [1.339103  , 0.        , 0.        , ..., 0.28090587, 0.        ,
#          0.        ],
#         [1.3295076 , 0.        , 0.        , ..., 0.28449622, 0.        ,
#          0.        ],
#         ...,
#         [1.329447  , 0.        , 0.        , ..., 0.29891258, 0.        ,
#          0.        ],
#         [1.3275185 , 0.        , 0.        , ..., 0.27982977, 0.        ,
#          0.        ],
#         [1.3398709 , 0.        , 0.        , ..., 0.28746986, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3489821 , 0.        , 0.        , ..., 0.30354014, 0.        ,
#          0.        ],
#         [1.3365242 , 0.        , 0.        , ..., 0.29785445, 0.        ,
#          0.        ],
#         [1.3494604 , 0.        , 0.        , ..., 0.3008974 , 0.        ,
#          0.        ],
#         ...,
#         [1.3364358 , 0.        , 0.        , ..., 0.29728085, 0.        ,
#          0.        ],
#         [1.3339944 , 0.        , 0.        , ..., 0.30279168, 0.        ,
#          0.        ],
#         [1.3420956 , 0.        , 0.        , ..., 0.32724947, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3333468 , 0.        , 0.        , ..., 0.28377652, 0.        ,
#          0.        ],
#         [1.344539  , 0.        , 0.        , ..., 0.3110585 , 0.        ,
#          0.        ],
#         [1.3519498 , 0.        , 0.        , ..., 0.32453322, 0.        ,
#          0.        ],
#         ...,
#         [1.331943  , 0.        , 0.        , ..., 0.29152745, 0.        ,
#          0.        ],
#         [1.353512  , 0.        , 0.        , ..., 0.30471984, 0.        ,
#          0.        ],
#         [1.357944  , 0.        , 0.        , ..., 0.3158025 , 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3570302 , 0.        , 0.        , ..., 0.3407793 , 0.        ,
#          0.        ],
#         [1.3372288 , 0.        , 0.        , ..., 0.29537618, 0.        ,
#          0.        ],
#         [1.3509994 , 0.        , 0.        , ..., 0.29763308, 0.        ,
#          0.        ],
#         ...,
#         [1.3515728 , 0.        , 0.        , ..., 0.32033515, 0.        ,
#          0.        ],
#         [1.3425014 , 0.        , 0.        , ..., 0.28350344, 0.        ,
#          0.        ],
#         [1.33456   , 0.        , 0.        , ..., 0.28734183, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3377739 , 0.        , 0.        , ..., 0.315803  , 0.        ,
#          0.        ],
#         [1.3383336 , 0.        , 0.        , ..., 0.29775235, 0.        ,
#          0.        ],
#         [1.3348858 , 0.        , 0.        , ..., 0.2831632 , 0.        ,
#          0.        ],
#         ...,
#         [1.3666447 , 0.        , 0.        , ..., 0.33744702, 0.        ,
#          0.        ],
#         [1.3360989 , 0.        , 0.        , ..., 0.27593777, 0.        ,
#          0.        ],
#         [1.3333192 , 0.        , 0.        , ..., 0.28488988, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.352545  , 0.00633001, 0.        , ..., 0.28947648, 0.01144736,
#          0.        ],
#         [1.3323783 , 0.        , 0.        , ..., 0.28515536, 0.        ,
#          0.        ],
#         [1.3306543 , 0.        , 0.        , ..., 0.29474223, 0.        ,
#          0.        ],
#         ...,
#         [1.3350646 , 0.        , 0.        , ..., 0.28307587, 0.        ,
#          0.        ],
#         [1.345748  , 0.        , 0.        , ..., 0.32450676, 0.        ,
#          0.        ],
#         [1.3546257 , 0.        , 0.        , ..., 0.29481548, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3344238 , 0.        , 0.        , ..., 0.27982676, 0.        ,
#          0.        ],
#         [1.3455869 , 0.        , 0.        , ..., 0.31529596, 0.        ,
#          0.        ],
#         [1.3396561 , 0.        , 0.        , ..., 0.29466167, 0.        ,
#          0.        ],
#         ...,
#         [1.3432763 , 0.        , 0.        , ..., 0.32897657, 0.        ,
#          0.        ],
#         [1.3383788 , 0.        , 0.        , ..., 0.315507  , 0.        ,
#          0.        ],
#         [1.3430164 , 0.        , 0.        , ..., 0.29093987, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3301195 , 0.        , 0.        , ..., 0.27575397, 0.        ,
#          0.        ],
#         [1.3378562 , 0.        , 0.        , ..., 0.29202843, 0.        ,
#          0.        ],
#         [1.3594933 , 0.        , 0.        , ..., 0.30152464, 0.        ,
#          0.        ],
#         ...,
#         [1.3386518 , 0.        , 0.        , ..., 0.31387302, 0.        ,
#          0.        ],
#         [1.3348291 , 0.        , 0.        , ..., 0.30022392, 0.        ,
#          0.        ],
#         [1.3450935 , 0.        , 0.        , ..., 0.33095896, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3531351 , 0.        , 0.        , ..., 0.31734556, 0.        ,
#          0.        ],
#         [1.3399584 , 0.        , 0.        , ..., 0.31895578, 0.        ,
#          0.        ],
#         [1.3311911 , 0.        , 0.        , ..., 0.29092658, 0.        ,
#          0.        ],
#         ...,
#         [1.3609765 , 0.        , 0.        , ..., 0.312249  , 0.        ,
#          0.        ],
#         [1.3496139 , 0.        , 0.        , ..., 0.31845555, 0.        ,
#          0.        ],
#         [1.3416588 , 0.        , 0.        , ..., 0.30679753, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3452165 , 0.        , 0.        , ..., 0.2856113 , 0.        ,
#          0.        ],
#         [1.3370435 , 0.        , 0.        , ..., 0.3424494 , 0.        ,
#          0.        ],
#         [1.3671227 , 0.        , 0.        , ..., 0.34148684, 0.        ,
#          0.        ],
#         ...,
#         [1.3361151 , 0.        , 0.        , ..., 0.34020787, 0.        ,
#          0.        ],
#         [1.3244486 , 0.        , 0.        , ..., 0.31654724, 0.        ,
#          0.        ],
#         [1.3407743 , 0.        , 0.        , ..., 0.30568975, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3456855 , 0.        , 0.        , ..., 0.30106646, 0.        ,
#          0.        ],
#         [1.3365697 , 0.        , 0.        , ..., 0.28350455, 0.        ,
#          0.        ],
#         [1.3501854 , 0.        , 0.        , ..., 0.32839864, 0.        ,
#          0.        ],
#         ...,
#         [1.3737184 , 0.        , 0.        , ..., 0.3322894 , 0.        ,
#          0.        ],
#         [1.3458735 , 0.        , 0.        , ..., 0.30129045, 0.        ,
#          0.        ],
#         [1.3421364 , 0.        , 0.        , ..., 0.29573897, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3371354 , 0.        , 0.        , ..., 0.28999892, 0.        ,
#          0.        ],
#         [1.3694935 , 0.        , 0.        , ..., 0.3125443 , 0.        ,
#          0.        ],
#         [1.3356776 , 0.        , 0.        , ..., 0.283571  , 0.        ,
#          0.        ],
#         ...,
#         [1.334361  , 0.        , 0.        , ..., 0.2977984 , 0.        ,
#          0.        ],
#         [1.3515109 , 0.        , 0.        , ..., 0.29603994, 0.        ,
#          0.        ],
#         [1.3432622 , 0.        , 0.        , ..., 0.33493   , 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3375114 , 0.        , 0.        , ..., 0.28413957, 0.        ,
#          0.        ],
#         [1.3390685 , 0.        , 0.        , ..., 0.28995925, 0.        ,
#          0.        ],
#         [1.3291346 , 0.        , 0.        , ..., 0.27770108, 0.        ,
#          0.        ],
#         ...,
#         [1.3888547 , 0.        , 0.        , ..., 0.30689228, 0.        ,
#          0.        ],
#         [1.3320632 , 0.        , 0.        , ..., 0.2913937 , 0.        ,
#          0.        ],
#         [1.3296168 , 0.        , 0.        , ..., 0.28783125, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3521816 , 0.        , 0.        , ..., 0.30258107, 0.        ,
#          0.        ],
#         [1.331634  , 0.        , 0.        , ..., 0.28644007, 0.        ,
#          0.        ],
#         [1.3388782 , 0.        , 0.        , ..., 0.28529185, 0.        ,
#          0.        ],
#         ...,
#         [1.3264937 , 0.        , 0.        , ..., 0.28160554, 0.        ,
#          0.        ],
#         [1.3442578 , 0.        , 0.        , ..., 0.32820272, 0.        ,
#          0.        ],
#         [1.344799  , 0.        , 0.        , ..., 0.30191225, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3389179 , 0.        , 0.        , ..., 0.2875485 , 0.        ,
#          0.        ],
#         [1.345078  , 0.        , 0.        , ..., 0.31683224, 0.        ,
#          0.        ],
#         [1.3623784 , 0.        , 0.        , ..., 0.32266998, 0.        ,
#          0.        ],
#         ...,
#         [1.3640175 , 0.        , 0.        , ..., 0.32895255, 0.        ,
#          0.        ],
#         [1.334116  , 0.        , 0.        , ..., 0.29022086, 0.        ,
#          0.        ],
#         [1.3554521 , 0.        , 0.        , ..., 0.29965204, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3408376 , 0.        , 0.        , ..., 0.34084696, 0.        ,
#          0.        ],
#         [1.3353559 , 0.        , 0.        , ..., 0.3097843 , 0.        ,
#          0.        ],
#         [1.34178   , 0.        , 0.        , ..., 0.30073828, 0.        ,
#          0.        ],
#         ...,
#         [1.3313149 , 0.        , 0.        , ..., 0.27984092, 0.        ,
#          0.        ],
#         [1.3375477 , 0.        , 0.        , ..., 0.2971369 , 0.        ,
#          0.        ],
#         [1.3450341 , 0.        , 0.        , ..., 0.30997264, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3533471 , 0.        , 0.        , ..., 0.31200546, 0.        ,
#          0.        ],
#         [1.3377604 , 0.        , 0.        , ..., 0.283531  , 0.        ,
#          0.        ],
#         [1.3404367 , 0.        , 0.        , ..., 0.30044305, 0.        ,
#          0.        ],
#         ...,
#         [1.3509195 , 0.        , 0.        , ..., 0.28663003, 0.        ,
#          0.        ],
#         [1.3320209 , 0.        , 0.        , ..., 0.2800568 , 0.        ,
#          0.        ],
#         [1.3353102 , 0.        , 0.        , ..., 0.29295605, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3365767 , 0.        , 0.        , ..., 0.2880395 , 0.        ,
#          0.        ],
#         [1.3355023 , 0.        , 0.        , ..., 0.3097201 , 0.        ,
#          0.        ],
#         [1.3377054 , 0.        , 0.        , ..., 0.29297525, 0.        ,
#          0.        ],
#         ...,
#         [1.3312602 , 0.        , 0.        , ..., 0.28515396, 0.        ,
#          0.        ],
#         [1.3409098 , 0.        , 0.        , ..., 0.3353446 , 0.        ,
#          0.        ],
#         [1.3319063 , 0.        , 0.        , ..., 0.28276488, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3296902 , 0.        , 0.        , ..., 0.33245108, 0.        ,
#          0.        ],
#         [1.3291552 , 0.        , 0.        , ..., 0.28280073, 0.        ,
#          0.        ],
#         [1.3584307 , 0.        , 0.        , ..., 0.3032128 , 0.        ,
#          0.        ],
#         ...,
#         [1.3366412 , 0.        , 0.        , ..., 0.31993234, 0.        ,
#          0.        ],
#         [1.337913  , 0.        , 0.        , ..., 0.29910856, 0.        ,
#          0.        ],
#         [1.356763  , 0.        , 0.        , ..., 0.3103078 , 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3329805 , 0.        , 0.        , ..., 0.282026  , 0.        ,
#          0.        ],
#         [1.3409892 , 0.        , 0.        , ..., 0.31495467, 0.        ,
#          0.        ],
#         [1.3548484 , 0.        , 0.        , ..., 0.33052704, 0.        ,
#          0.        ],
#         ...,
#         [1.3399822 , 0.        , 0.        , ..., 0.3074171 , 0.        ,
#          0.        ],
#         [1.3660078 , 0.        , 0.        , ..., 0.3295449 , 0.        ,
#          0.        ],
#         [1.3405652 , 0.        , 0.        , ..., 0.29743898, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3710325e+00, 0.0000000e+00, 0.0000000e+00, ..., 3.1191301e-01,
#          1.5708057e-02, 0.0000000e+00],
#         [1.3311645e+00, 0.0000000e+00, 0.0000000e+00, ..., 2.8613633e-01,
#          0.0000000e+00, 0.0000000e+00],
#         [1.3470019e+00, 0.0000000e+00, 0.0000000e+00, ..., 2.9173344e-01,
#          0.0000000e+00, 0.0000000e+00],
#         ...,
#         [1.3474061e+00, 0.0000000e+00, 0.0000000e+00, ..., 3.0983657e-01,
#          0.0000000e+00, 0.0000000e+00],
#         [1.3537421e+00, 0.0000000e+00, 0.0000000e+00, ..., 2.8863814e-01,
#          3.0788779e-04, 0.0000000e+00],
#         [1.3328091e+00, 0.0000000e+00, 0.0000000e+00, ..., 2.8385997e-01,
#          0.0000000e+00, 0.0000000e+00]], dtype=float32),
#  array([[1.3762019 , 0.        , 0.        , ..., 0.29880506, 0.00168518,
#          0.        ],
#         [1.355137  , 0.        , 0.        , ..., 0.30360472, 0.        ,
#          0.        ],
#         [1.3493071 , 0.        , 0.        , ..., 0.2999425 , 0.        ,
#          0.        ],
#         ...,
#         [1.3401093 , 0.        , 0.        , ..., 0.30382222, 0.        ,
#          0.        ],
#         [1.3308332 , 0.        , 0.        , ..., 0.2912649 , 0.        ,
#          0.        ],
#         [1.3416595 , 0.        , 0.        , ..., 0.30189013, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3376739 , 0.        , 0.        , ..., 0.2970314 , 0.        ,
#          0.        ],
#         [1.356951  , 0.        , 0.        , ..., 0.34159523, 0.        ,
#          0.        ],
#         [1.3506911 , 0.        , 0.        , ..., 0.3280601 , 0.        ,
#          0.        ],
#         ...,
#         [1.3387568 , 0.        , 0.        , ..., 0.28513452, 0.        ,
#          0.        ],
#         [1.3586841 , 0.        , 0.        , ..., 0.29689956, 0.        ,
#          0.        ],
#         [1.3506217 , 0.        , 0.        , ..., 0.33942986, 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.335398  , 0.        , 0.        , ..., 0.32336372, 0.        ,
#          0.        ],
#         [1.377742  , 0.        , 0.        , ..., 0.31402838, 0.        ,
#          0.        ],
#         [1.3343325 , 0.        , 0.        , ..., 0.28882328, 0.        ,
#          0.        ],
#         ...,
#         [1.3333821 , 0.        , 0.        , ..., 0.29050982, 0.        ,
#          0.        ],
#         [1.340055  , 0.        , 0.        , ..., 0.30651423, 0.        ,
#          0.        ],
#         [1.349069  , 0.        , 0.        , ..., 0.3327337 , 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.3333936 , 0.        , 0.        , ..., 0.29384857, 0.        ,
#          0.        ],
#         [1.3315254 , 0.        , 0.        , ..., 0.28108862, 0.        ,
#          0.        ],
#         [1.335047  , 0.        , 0.        , ..., 0.28059596, 0.        ,
#          0.        ],
#         ...,
#         [1.3417857 , 0.        , 0.        , ..., 0.3266542 , 0.        ,
#          0.        ],
#         [1.3333406 , 0.        , 0.        , ..., 0.29224372, 0.        ,
#          0.        ],
#         [1.3306632 , 0.        , 0.        , ..., 0.28601426, 0.        ,
#          0.        ]], dtype=float32),
#  ...]

# %%
u = np.concatenate(np.array(representations_list, dtype=object), axis=0)

# %%
u = u.astype(np.float32)

# %%
u
# Out:
# array([[  2.896883  , -14.403749  ,  -1.1453178 , ...,   6.710001  ,
#         -32.794464  , -16.505445  ],
#        [ -9.098314  , -19.344925  ,  -0.98259765, ...,  -2.810565  ,
#         -19.627369  , -13.571489  ],
#        [ 41.789757  , -17.871307  ,   8.972931  , ...,  19.91785   ,
#         -22.871788  ,   5.4442782 ],
#        ...,
#        [ 38.807243  , -19.207182  ,  10.323062  , ...,  24.99525   ,
#         -29.436111  ,  -0.06830557],
#        [ 28.970936  , -24.529718  ,  18.154657  , ...,  17.122007  ,
#         -35.05682   ,  -8.650463  ],
#        [ -0.05795199, -16.675604  ,   6.595265  , ...,   7.324127  ,
#         -26.487509  , -12.954288  ]], dtype=float32)

# %%
from sklearn.cluster import AgglomerativeClustering
clustering = AgglomerativeClustering(n_clusters=5)

# %%
clustering.fit(u)

# %%
d = clustering.labels_

# %%
d

# %%
sns.histplot(d, discrete=True)
plt.show()

# %%
u = pd.DataFrame(representations_list[0])
y = pd.DataFrame(representations_list[0])
u

# %%
u.loc[ :] = y

# %%
pd.concat((u,y)).reset_index(drop=True)

# %%
io = pd.DataFrame(np.zeros((1,128)))
io.to_csv('representations_per_epoch.csv', index=False)

# %%
x.loc[:,:] = j

# %%
x

# %%
for i in range(len(ll)):
    ll[i] = np.squeeze(ll[i])

# %%
# !pip install -U scikit-learn
# !pip install matplotlib
# !pip install seaborn

# %%
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import MiniBatchKMeans
from sklearn.cluster import Birch
from matplotlib import pyplot as plt
from mpl_toolkits import mplot3d
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import pandas as pd
import seaborn as sns

# %%
ll

# %%
arr = np.array(ll)

# %%
arr.shape

# %%
arr[1].shape

# %%
kmeans = MiniBatchKMeans(n_clusters=5).fit_predict(u)#Birch(n_clusters=5).fit_predict(arr)#KMeans(n_clusters=5, init='random', algorithm='full').fit(ll)

# %%
d = kmeans.predict(u)

# %%
u = u.astype(np.float32)

# %%
u.shape

# %%
m = kmeans

# %%
sns.histplot(d, discrete=True)
plt.show()

# %%
d

# %%
m.shape

# %%
c0 = np.where(m==0)
c1 = np.where(m==1)
c2 = np.where(m==2)
c3 = np.where(m==3)
c4 = np.where(m==4)

# %%
clusters = [np.where(kmeans==c)[0].shape[0] for c in range(5)]

# %%
max(clusters)

# %%
clusters

# %%
m

# %%
print(c0[0].shape[0],c1[0].shape[0],c2[0].shape[0],c3[0].shape[0],c4[0].shape[0] )

# %%
pseudolabels = pd.DataFrame(m)
pseudolabels

# %%
df = pd.read_csv('nair_unbalanced_train.csv')
df['pseudolabels'] = pseudolabels
df

# %%
majority = max(c0[0].shape[0],c1[0].shape[0],c2[0].shape[0],c3[0].shape[0],c4[0].shape[0])
majority
ratio0 = majority / c0[0].shape[0]
ratio1 = majority / c1[0].shape[0]
ratio2 = majority / c2[0].shape[0]
ratio3 = majority / c3[0].shape[0]
ratio4 = majority / c4[0].shape[0]

# %%
df = df.sort_values(by=['new_class']).reset_index(drop=True)
df

# %%
df0 = df[df['pseudolabels']==0]
df1 = df[df['pseudolabels']==1]
df2 = df[df['pseudolabels']==2]
df3 = df[df['pseudolabels']==3]
df4 = df[df['pseudolabels']==4]

# %%
df4

# %%
ss0 = df0.loc[df0.index.repeat(1 if ratio0 ==1 else round(ratio0)+1)]
ss1 = df1.loc[df1.index.repeat(1 if ratio1 ==1 else round(ratio1)+1)]
ss2 = df2.loc[df2.index.repeat(1 if ratio2 ==1 else round(ratio2)+1)]
ss3 = df3.loc[df3.index.repeat(1 if ratio3 ==1 else round(ratio3)+1)]
ss4 = df4.loc[df4.index.repeat(1 if ratio4 ==1 else round(ratio4)+1)]

# %%
true0 = ss0['new_class'].to_numpy()
sns.histplot(true0, discrete=True)
plt.show()

# %%
true1 = ss1['new_class'].to_numpy()
sns.histplot(true1, discrete=True)
plt.show()

# %%
true2 = ss2['new_class'].to_numpy()
sns.histplot(true2, discrete=True)
plt.show()

# %%
true3 = ss3['new_class'].to_numpy()
sns.histplot(true3, discrete=True)
plt.show()

# %%
true4 = ss4['new_class'].to_numpy()
sns.histplot(true4, discrete=True)
plt.show()

# %%
s0 = ss0.sample(n=3584, replace = True).reset_index(drop=True)
s1 = ss1.sample(n=3584,replace = True).reset_index(drop=True)
s2 = ss2.sample(n=3584,replace = True).reset_index(drop=True)
s3 = ss3.sample(n=3584,replace = True).reset_index(drop=True)
s4 = ss4.sample(n=3584,replace = True).reset_index(drop=True)

join = [s0,s1,s2,s3,s4]
join = pd.concat(join).reset_index(drop=True)

a = join['new_class'].to_numpy()
b = join['pseudolabels'].to_numpy()

# %%
sns.histplot(a, discrete=True)
plt.show()

# %%
sns.histplot(b, discrete=True)
plt.show()

# %%
join

# %%
d = [df[df['pseudolabels']==s].reset_index(drop=True) for s in range(5)]

# %%
by_psudolabels = [df[df['pseudolabels']==label].reset_index(drop=True)
                        for label in range(5)]
by_psudolabels

# %%
dd = []
for dataframe in d:
    ratio = majority/dataframe.shape[0]
    new_dataframe = dataframe.loc[dataframe.index.repeat(1 if ratio==1.0 else round(ratio)+1)]
    new_dataframe = new_dataframe.sample(n=majority).reset_index(drop=True)
    dd.append(new_dataframe)
del d

# %%
dd = pd.concat(dd).reset_index(drop=True)
dd

# %%
concat = pd.concat(dd).reset_index(drop=True)
concat = concat.sample(frac=1).reset_index(drop=True)
namess = concat['name'].to_numpy()
labels_true = concat['new_class'].to_numpy()
labels_fake = concat['pseudolabels'].to_numpy()
concat

# %%
namess[0]

# %%
plt.hist(labels_true, bins = 5)
plt.show()

# %%
labels_true.shape

# %%
plt.hist(labels_fake, bins = 5)
plt.show()

# %%
pca = PCA(n_components=3).fit_transform(arr)

# %%
fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
ax.scatter3D(pca[:,0], pca[:,1], pca[:,2], color = "blue")
plt.show()

# %%
kmeans2 = KMeans(n_clusters=5, init='random').fit(pca)
plt.hist(kmeans.labels_, bins = 5)
plt.show()

# %%
pca2 = PCA(n_components=2).fit_transform(arr)
labels = KMeans(5, random_state=0).fit_predict(pca2)
plt.scatter(pca2[:, 0], pca2[:, 1], c=labels,
            s=50, cmap='viridis');

# %%
plt.hist(labels, bins = 5)
plt.show()

# %%
tsn = TSNE(n_components=2, perplexity=50).fit_transform(arr)

# %%
plt.scatter(tsn[:, 0], tsn[:, 1], c=labels,
            s=50, cmap='viridis');

# %%
plt.hist(labels, bins = 5)
plt.show()

# %%
df = pd.read_csv('nair_unbalanced_train.csv')
file_paths = df['name'].values
labels = df['new_class'].values

# %%
sns.histplot(labels, discrete=True)
plt.show()

# %%
df

# %%
df.sort_values(by=['new_class'])

# %%
d2 = df[df['new_class']==2]

# %%
# !pip install yellowbrick

# %%
from yellowbrick.cluster import SilhouetteVisualizer

fig, ax = plt.subplots(3, 2, figsize=(15,8))
for i in [2, 3, 4, 5, 6, 7]:
    '''
    Create KMeans instance for different number of clusters
    '''
    km = KMeans(n_clusters=i, init='k-means++', n_init=10, max_iter=100, random_state=42)
    q, mod = divmod(i, 2)
    '''
    Create SilhouetteVisualizer instance with KMeans instance
    Fit the visualizer
    '''
    visualizer = SilhouetteVisualizer(km, colors='yellowbrick', ax=ax[q-1][mod])
    visualizer.fit(arr)

# %%
kmeans = KMeans(n_clusters=2).fit_predict(arr)
kmeans

# %%
sns.histplot(kmeans, discrete=True)
plt.show()

# %%
c0 = np.where(kmeans==0)
c1 = np.where(kmeans==1)

# %%
print(c0[0].shape[0],c1[0].shape[0])

# %%
pseudolabels = pd.DataFrame(kmeans)
df = pd.read_csv('nair_unbalanced_train.csv')
df['pseudolabels'] = pseudolabels
df

# %%
df0 = df[df['pseudolabels']==0]
df1 = df[df['pseudolabels']==1]

# %%
np.where(df0['new_class']==0)[0].shape

# %%
ss = df0['pseudolabels'].to_numpy()
s = df1['pseudolabels'].to_numpy()

# %%
d = np.where(df['pseudolabels']==0)
dd = arr[d[0]]
e = np.where(df['pseudolabels']==1)
ee = arr[e[0]]

# %%
ee.shape

# %%
from yellowbrick.cluster import SilhouetteVisualizer

fig, ax = plt.subplots(3, 2, figsize=(15,8))
for i in [2, 3, 4, 5, 6, 7]:
    '''
    Create KMeans instance for different number of clusters
    '''
    km = KMeans(n_clusters=i, init='k-means++', n_init=10, max_iter=100, random_state=42)
    q, mod = divmod(i, 2)
    '''
    Create SilhouetteVisualizer instance with KMeans instance
    Fit the visualizer
    '''
    visualizer = SilhouetteVisualizer(km, colors='yellowbrick', ax=ax[q-1][mod])
    visualizer.fit(dd)

# %%
from yellowbrick.cluster import SilhouetteVisualizer

fig, ax = plt.subplots(3, 2, figsize=(15,8))
for i in [2, 3, 4, 5, 6, 7]:
    '''
    Create KMeans instance for different number of clusters
    '''
    km = KMeans(n_clusters=i, init='k-means++', n_init=10, max_iter=100, random_state=42)
    q, mod = divmod(i, 2)
    '''
    Create SilhouetteVisualizer instance with KMeans instance
    Fit the visualizer
    '''
    visualizer = SilhouetteVisualizer(km, colors='yellowbrick', ax=ax[q-1][mod])
    visualizer.fit(ee)

# %%
km = KMeans(n_clusters=2).fit_predict(dd)
km

# %%
sns.histplot(km, discrete=True)
plt.show()

# %%
df['new_lbls'] = 0 
df['new_lbls'][d[0]] = km

# %%
df

# %%
km1 = KMeans(n_clusters=3).fit_predict(ee)
km1 = km1 + 2

# %%
sns.histplot(km1, discrete=True)
plt.show()

# %%
df['new_lbls'][e[0]] = km1
df

# %%
c0 = np.where(df['new_lbls']==0)
c1 = np.where(df['new_lbls']==1)
c2 = np.where(df['new_lbls']==2)
c3 = np.where(df['new_lbls']==3)
c4 = np.where(df['new_lbls']==4)

# %%
ratio0 = majority / c0[0].shape[0]
ratio1 = majority / c1[0].shape[0]
ratio2 = majority / c2[0].shape[0]
ratio3 = majority / c3[0].shape[0]
ratio4 = majority / c4[0].shape[0]

# %%
df0 = df[df['new_lbls']==0]
df1 = df[df['new_lbls']==1]
df2 = df[df['new_lbls']==2]
df3 = df[df['new_lbls']==3]
df4 = df[df['new_lbls']==4]

# %%
ss0 = df0.loc[df0.index.repeat(1 if ratio0 ==1 else round(ratio0)+1)]
ss1 = df1.loc[df1.index.repeat(1 if ratio1 ==1 else round(ratio1)+1)]
ss2 = df2.loc[df2.index.repeat(1 if ratio2 ==1 else round(ratio2)+1)]
ss3 = df3.loc[df3.index.repeat(1 if ratio3 ==1 else round(ratio3)+1)]
ss4 = df4.loc[df4.index.repeat(1 if ratio4 ==1 else round(ratio4)+1)]

# %%
s0 = ss0.sample(n=3214, replace = True).reset_index(drop=True)
s1 = ss1.sample(n=3214,replace = True).reset_index(drop=True)
s2 = ss2.sample(n=3214,replace = True).reset_index(drop=True)
s3 = ss3.sample(n=3214,replace = True).reset_index(drop=True)
s4 = ss4.sample(n=3214,replace = True).reset_index(drop=True)

join = [s0,s1,s2,s3,s4]
join = pd.concat(join).reset_index(drop=True)

a = join['new_class'].to_numpy()
b = join['pseudolabels'].to_numpy()

# %%
majority = max(c0[0].shape[0],c1[0].shape[0],c2[0].shape[0],c3[0].shape[0],c4[0].shape[0])
majority

# %%
sns.histplot(a, discrete=True)
plt.show()

# %%
r = sns.histplot(f, discrete=True)
plt.show()

# %%
def get_new_ds(representations):

    representations = representations.numpy()

    pseudolabels = MiniBatchKMeans(n_clusters = 5).fit_predict(representations)
    cluster_length = [np.where(pseudolabels==c)[0].shape[0] for c in range(5)]
    larger_cluster_length = max(cluster_length)

    df = pd.read_csv('nair_unbalanced_train.csv')
    df['pseudolabels'] = pseudolabels

    by_psudolabels = [df[df['pseudolabels']==label].reset_index(drop=True)
                        for label in range(5)]

    extended_dataframes = []
    for dataframe in by_psudolabels:
        ratio = larger_cluster_length/dataframe.shape[0]
        extended_dataframe = dataframe.loc[dataframe.index.repeat(1 if ratio==1.0 else round(ratio)+1)]
        extended_dataframe = extended_dataframe.sample(n=larger_cluster_length).reset_index(drop=True)
        extended_dataframes.append(extended_dataframe)
    
    del by_psudolabels

    extended_dataframes = pd.concat(extended_dataframes).reset_index(drop=True)
    extended_dataframes = extended_dataframes.sample(frac=1).reset_index(drop=True)

    return extended_dataframes

# %%
o = iterator.get_next()

# %%
dz= o[0][1]

# %%
img1=dz[:,:,:3]
img2=dz[:,:,3:]

# %%
plt.imshow(img1, interpolation='nearest')
plt.show()

# %%
plt.imshow(img2, interpolation='nearest')
plt.show()

# %%
o
